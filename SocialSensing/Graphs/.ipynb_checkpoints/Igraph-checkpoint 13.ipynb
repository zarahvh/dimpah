# %% [markdown]
# # R graphs and Gephi
#
# This exercise will teach you how to use Python together with the popular visualisation environment Igraph.
# The paper you read today, used both to perfection: Pablo Barbera, John T. Jost, Jonathan Nagler, Joshua Tucker, and Richard Bonneau: "Tweeting from Left to Right: Is Online Political Communication More Than an Echo Chamber?".
#
# Check out the paper's code at https://github.com/pablobarbera/echo_chambers and in particular https://github.com/pablobarbera/echo_chambers/blob/master/03_analysis/14-network-visualization.r, which produces all the wonderful network visualisations you have seen in the text. If we would have access to the data we could just rerun the analysis.
#
# The exercise today will teach you how to produce such Igraph graphs based on an Python analysis. Well, we will take the first steps at least.

# %% [markdown]
# ## Delitsch School Class Network
#
# Our first example is the friendship network of a German boys' school class from 1880/1881. It's based on the probably first ever collected social network dataset, assembled by the primary school teacher Johannes Delitsch. The data was reanalyzed and compiled for the article: Heidler, R., Gamper, M., Herz, A., Eßer, F. (2014): Relationship patterns in the 19th century: The friendship network in a German boys' school class from 1880 to 1881 revisited. Social Networks 13: 1--13..
#
# Let's load igraph first.

# %%
import igraph
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## The Data
# The Delitsch data is prepared for you. You can load it with igraph.read() from igraph.

# %%
g = igraph.read("Delitsch-Network.gml ", format="gml")

# %% [markdown]
# Check out the vertices (nodes) labels and create a quick plot of the graph.

# %%
from igraph import *

summary(g)
print(g)
# Out:
# IGRAPH D--- 53 179 --
# + attr: Handicapped (v), Lokationposition1highest53lowest (v), Repeater (v), Sweetsgiver (v), graphics (v), id (v), label (v), id (e), value (e)
# IGRAPH D--- 53 179 --
# + attr: Handicapped (v), Lokationposition1highest53lowest (v), Repeater (v),
#   Sweetsgiver (v), graphics (v), id (v), label (v), id (e), value (e)
# + edges:
#  0 ->  3  4 36                              29 ->  0 13 45 49
#  1 -> 14 24 50                              30 -> 13 14 23 29 40
#  2 ->  1  3  8 15 35                        31 -> 35
#  3 ->  9 13 22 35 45 48                     32 -> 21 26
#  4 ->  0  5 13 23                           33 ->
#  5 ->  1  3  4 13                           34 ->  4
#  6 -> 10 15                                 35 ->  6 10 22 23 28 31 44 46 49
#  7 ->                                       36 -> 10 49
#  8 -> 40 49                                 37 ->  0  2 10 14 16 17 22 24 35
# 38 40 48
#  9 ->  3                                    38 -> 22 32 36
# 10 ->  6  8 13 14 27                        39 ->
# 11 -> 43                                    40 ->  8 12 20 23 50
# 12 -> 40                                    41 -> 16 22 44
# 13 ->  0 14 22 45                           42 -> 14 16 22 45
# 14 ->  4  5  6 13 16 22 24 45 50            43 ->  0 11
# 15 ->  2 13 14 18                           44 -> 14 15 21 30 40 43
# 16 -> 14                                    45 ->  0 13 14 22
# 17 ->  0 10 22 37 38 45                     46 -> 14 16
# 18 ->                                       47 ->
# 19 ->                                       48 -> 10 14 21 24 29 37 40 41 44
# 20 -> 40                                    49 ->  8 13 14 45
# 21 ->  0  1  2  5 10 14 20 40 43 48         50 -> 13 23 24
# 22 ->  4 13 14 45                           51 -> 13 18 45 52
# 23 ->  4 20 40 50                           52 -> 14 29 40 51
# 24 ->  1 48 50
# 25 -> 13 15 45
# 26 -> 32
# 27 -> 10
# 28 -> 14 22

# %%
import cairocffi
layout = g.layout("kk")
plot(g, layout = layout)

# %% [markdown]
# ### Simple Statistics with Python igraph
#
# To demonstrate that you can use Python as a statistical engine to support your Graphi work, we now run a few simple statistics.

# %%
# node degree
node_degree = g.degree(mode='all')
# degree distribution
degree_distr = g.degree_distribution(mode='all')

# %%
# ??
plt.plot(node_degree)

# %% [markdown]
# ### Change the graph
#
# Next we update the graph to prepare it for its Gephi visualisation. You should know already how this works.

# %%
plot(g, layout = layout, vertex_color='orange', edge_arrow_size=.2, edge_color='grey', edge_curved=False)

# %% [markdown]
# ### Hubs/Authorities
#
# Let's do one more example analysis. Network hubs are expected to contain vertices with a large number of outgoing links, while authorities would get many incoming links from hubs.
#
# Let's plot both.

# %%
hs = g.hub_score()
asc = g.authority_score()

# %%
plot(g, layout = layout, vertex_color='orange', vertex_size=g.hub_score()*20, edge_color='grey', edge_curved=False)

# %%
plot(g, layout = layout, vertex_color='orange', vertex_size=g.authority_score()*20, edge_color='grey', edge_curved=False)

# %% [markdown]
# ## Twitter Network Analysis
#
# The Delitsch network is quite interesting, but maybe you are more excited by being able to visualise Twitter networks?
#
# First we do our Twitter thing and set up the environment for searching Twitter from R. I have defined a token for you and use this opportunity to show you how to load it.

# %%
import requests
from ipynb.fs.full.keys import *
import tweepy

consumer_key = twit_key
consumer_secret = twit_secr
access_token = twit_token

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %% [markdown]
# Now we search Twitter for the 'truth'. Up to 100 recent Tweets.

# %%
tweets = api.search(q='truth', count =100)

# %%
# edges <- gt_edges(tweets, text, screen_name, status_id)
# #edges <- edges[!duplicated(edges),]
# nodes <- gt_nodes(edges, meta = TRUE)
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:47 +0000 2021', 'id': 1447540683527626752, 'id_str': '1447540683527626752', 'text': 'RT @IrrawaddyNews: Myanmar Under the Tatmadaw: Much Has Changed Since 1988\nhttps://t.co/yTyfwHMr8D\n\n#WhatsHappeningInMyanmar\n--------------…', 'truncated': False, 'entities': {'hashtags': [{'text': 'WhatsHappeningInMyanmar', 'indices': [100, 124]}], 'symbols': [], 'user_mentions': [{'screen_name': 'IrrawaddyNews', 'name': 'The Irrawaddy (Eng)', 'id': 57289662, 'id_str': '57289662', 'indices': [3, 17]}], 'urls': [{'url': 'https://t.co/yTyfwHMr8D', 'expanded_url': 'https://bit.ly/3mL02vU', 'display_url': 'bit.ly/3mL02vU', 'indices': [75, 98]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1348531359690620930, 'id_str': '1348531359690620930', 'name': 'アウンティハミン', 'screen_name': 'BOUQUET_BUCKET', 'location': 'United States', 'description': 'Sometimes you have to pick the gun up to put the gun down! Revolution never go backward!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 243, 'friends_count': 114, 'listed_count': 0, 'created_at': 'Mon Jan 11 07:25:23 +0000 2021', 'favourites_count': 26152, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 68636, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1435140483609620481/owhFuElx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1435140483609620481/owhFuElx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1348531359690620930/1630689798', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 10:27:26 +0000 2021', 'id': 1447509138456514563, 'id_str': '1447509138456514563', 'text': 'Myanmar Under the Tatmadaw: Much Has Changed Since 1988\nhttps://t.co/yTyfwHMr8D\n\n#WhatsHappeningInMyanmar\n---------… https://t.co/6sc8y5uvuU', 'truncated': True, 'entities': {'hashtags': [{'text': 'WhatsHappeningInMyanmar', 'indices': [81, 105]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/yTyfwHMr8D', 'expanded_url': 'https://bit.ly/3mL02vU', 'display_url': 'bit.ly/3mL02vU', 'indices': [56, 79]}, {'url': 'https://t.co/6sc8y5uvuU', 'expanded_url': 'https://twitter.com/i/web/status/1447509138456514563', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 57289662, 'id_str': '57289662', 'name': 'The Irrawaddy (Eng)', 'screen_name': 'IrrawaddyNews', 'location': 'Myanmar', 'description': 'Covering Burma & Southeast Asia', 'url': 'https://t.co/yZYCx4G4Vf', 'entities': {'url': {'urls': [{'url': 'https://t.co/yZYCx4G4Vf',  ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:47 +0000 2021', 'id': 1447540682994987009, 'id_str': '1447540682994987009', 'text': 'RT @RepAdamSchiff: It’s a simple question with a simpler answer: Was the 2020 election stolen from Donald Trump?\n\nNo. Unequivocally no.\n\nBu…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RepAdamSchiff', 'name': 'Adam Schiff', 'id': 29501253, 'id_str': '29501253', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1084541079410626560, 'id_str': '1084541079410626560', 'name': 'DeKalbCoTNDems', 'screen_name': 'DekalbTNDems', 'location': 'Smithville, TN', 'description': 'DeKalb County Democrats of Tennessee #WeAreTN https://t.co/jjR3eh6lTn #DemocratsDeliver🏳️\u200d🌈💜💙💚💛🧡❤️🏳️\u200d🌈', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/jjR3eh6lTn', 'expanded_url': 'https://secure.actblue.com/donate/dekalb-county-democratic-party--tn--1', 'display_url': 'secure.actblue.com/donate/dekalb-…', 'indices': [46, 69]}]}}, 'protected': False, 'followers_count': 1166, 'friends_count': 1842, 'listed_count': 4, 'created_at': 'Sun Jan 13 20:01:57 +0000 2019', 'favourites_count': 57892, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 27050, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1412503663839490049/oiaG3WkB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1412503663839490049/oiaG3WkB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1084541079410626560/1628505566', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Oct 10 18:34:44 +0000 2021', 'id': 1447269383286497286, 'id_str': '1447269383286497286', 'text': 'It’s a simple question with a simpler answer: Was the 2020 election stolen from Donald Trump?\n\nNo. Unequivocally no… https://t.co/Gcq6LOVhuf', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Gcq6LOVhuf', 'expanded_url': 'https://twitter.com/i/web/status/1447269383286497286', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 29501253, 'id_str': '29501253', 'name': 'Adam Schiff', 'screen_name': 'RepAdamSchiff', 'location': 'Burbank, CA', 'description': "Representing California's 28th Congressional District. Chairman of the House Intelligence Committee (@HouseIntel).", 'url': 'https://t.co/jkkSoNgclK', 'entities': {'url': {'urls': [{'url': 'https://t.co/jkkSoNgclK', 'expanded_url': 'http://schiff.house.gov/', 'display_url': 'schiff.h ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:47 +0000 2021', 'id': 1447540682378285062, 'id_str': '1447540682378285062', 'text': '@HoldthisLfam69 @EmilScottie @ShibaArchives In economics we often hear money is limited.have u ever seen gold miner… https://t.co/tqg75Tvsc3', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'HoldthisLfam69', 'name': 'Christopher Urbisci', 'id': 739670874857582592, 'id_str': '739670874857582592', 'indices': [0, 15]}, {'screen_name': 'EmilScottie', 'name': 'Knights crypto stuff', 'id': 1409752136666161157, 'id_str': '1409752136666161157', 'indices': [16, 28]}, {'screen_name': 'ShibaArchives', 'name': 'Shiba Inu', 'id': 1396074770811195394, 'id_str': '1396074770811195394', 'indices': [29, 43]}], 'urls': [{'url': 'https://t.co/tqg75Tvsc3', 'expanded_url': 'https://twitter.com/i/web/status/1447540682378285062', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1447252213936664579, 'in_reply_to_status_id_str': '1447252213936664579', 'in_reply_to_user_id': 739670874857582592, 'in_reply_to_user_id_str': '739670874857582592', 'in_reply_to_screen_name': 'HoldthisLfam69', 'user': {'id': 1400799485182103554, 'id_str': '1400799485182103554', 'name': 'Joselito Arlan De Jesus', 'screen_name': 'ArlanJoselito', 'location': '', 'description': 'Shiba Inu', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 8, 'friends_count': 20, 'listed_count': 0, 'created_at': 'Fri Jun 04 13:02:38 +0000 2021', 'favourites_count': 299, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 347, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1400804017677107201/Q6vizPO__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1400804017677107201/Q6vizPO__normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 47), id=1447540682378285062, id_str='1447540682378285062', text='@HoldthisLfam69 @EmilScottie @ShibaArchives In economics we often hear money is limited.have u ever seen gold miner… https://t.co/tqg75Tvsc3', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'HoldthisLfam69', 'name': 'Christopher Urbisci', 'id': 739670874857582592, 'id_str': '739670874857582592', 'indices': [0, 15]}, {'screen_name': 'EmilScottie', 'name': 'Knights crypto stuff', 'id': 1409752136666161157, 'id_str': '1409752136666161157', 'indices': [16, 28]}, {'screen_name': 'ShibaArchives', 'name': 'Shiba Inu', 'id': 1396074770811195394, 'id_str': '1396074770811195394', 'indices': [29, 43]}], 'urls': [{'url': 'https://t.co/tqg75Tvsc3', 'expanded_url': 'https://twitter.com/i/web/status/1447540682378285062', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Androi ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:47 +0000 2021', 'id': 1447540682214739971, 'id_str': '1447540682214739971', 'text': 'RT @bedfordyid: "The rich, the famous and the powerful don’t like criticism and don’t like having their dirty laundry aired in public. They…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'bedfordyid', 'name': 'TTID 💙NHS ☣️ ⬅️2m➡️ ☣️ #FBPPR #FBPA', 'id': 2741929095, 'id_str': '2741929095', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1301464934006620160, 'id_str': '1301464934006620160', 'name': 'Harry Burgess', 'screen_name': 'HarryBu20084568', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 92, 'friends_count': 172, 'listed_count': 0, 'created_at': 'Thu Sep 03 10:20:29 +0000 2020', 'favourites_count': 6438, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4216, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1301465463763992576/T6axhgPt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1301465463763992576/T6axhgPt_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 12:20:08 +0000 2021', 'id': 1447537498796740608, 'id_str': '1447537498796740608', 'text': '"The rich, the famous and the powerful don’t like criticism and don’t like having their dirty laundry aired in publ… https://t.co/ebQ1xDOssV', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ebQ1xDOssV', 'expanded_url': 'https://twitter.com/i/web/status/1447537498796740608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2741929095, 'id_str': '2741929095', 'name': 'TTID 💙NHS ☣️ ⬅️2m➡️ ☣️ #FBPPR #FBPA', 'screen_name': 'bedfordyid', 'location': 'Bedford, England', 'description': 'Tory criminality knows no bounds, police turn a blind eye, corruption is rife, honours for favours, Cressida Dick is guilty by association #CoverUp #Corruption', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2211, 'friends_count': 2388, 'listed_count': 10, 'created_at': 'Wed Aug 13 18:26:18 +0000 2014', 'favourites_count': 280699, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 57791, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_u ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:46 +0000 2021', 'id': 1447540680797085705, 'id_str': '1447540680797085705', 'text': "@prageru Morning! Truth still matters! So don't let Not a University BIG LIE Charlatan @DennisPrager get you down!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'prageru', 'name': 'PragerU', 'id': 41160276, 'id_str': '41160276', 'indices': [0, 8]}, {'screen_name': 'DennisPrager', 'name': 'Dennis Prager', 'id': 17091571, 'id_str': '17091571', 'indices': [87, 100]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1447532437584547843, 'in_reply_to_status_id_str': '1447532437584547843', 'in_reply_to_user_id': 41160276, 'in_reply_to_user_id_str': '41160276', 'in_reply_to_screen_name': 'prageru', 'user': {'id': 19971406, 'id_str': '19971406', 'name': 'Dr. Wendy Lynne Lee', 'screen_name': 'THEWRENCHLEFT', 'location': 'Pennsylvania, U.S.A.', 'description': 'Writer. PhD. Philosophy professor. Climate, human rights, and animal welfare defender. Feminist. Blocked by Jack Posobiec. I have things to say.', 'url': 'https://t.co/lkelhOMYmc', 'entities': {'url': {'urls': [{'url': 'https://t.co/lkelhOMYmc', 'expanded_url': 'https://bloomu.academia.edu/WendyLee', 'display_url': 'bloomu.academia.edu/WendyLee', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 910, 'friends_count': 2546, 'listed_count': 22, 'created_at': 'Tue Feb 03 13:51:34 +0000 2009', 'favourites_count': 17020, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 30305, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1343195567674040320/_evG4Sdl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1343195567674040320/_evG4Sdl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19971406/1630849539', 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 46), id=1447540680797085705, id_str='1447540680797085705', text="@prageru Morning! Truth still matters! So don't let Not a University BIG LIE Charlatan @DennisPrager get you down!", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'prageru', 'name': 'PragerU', 'id': 41160276, 'id_str': '41160276', 'indices': [0, 8]}, {'screen_name': 'DennisPrager', 'name': 'Dennis Prager', 'id': 17091571, 'id_str': '17091571', 'indices': [87, 100]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1447532437584547843, in_reply_to_status_id_str='1447532437584547843', in_reply_to_user_id=41160276, in_reply_to_user_id_str='41160276', in_reply_to_screen_name='prageru', author=User(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'id': 1 ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:46 +0000 2021', 'id': 1447540679492751363, 'id_str': '1447540679492751363', 'text': 'Intentionally increasing harm to all of us, with the sole aim of having someone to blame for its own mounting inade… https://t.co/Yo5hGnNhre', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Yo5hGnNhre', 'expanded_url': 'https://twitter.com/i/web/status/1447540679492751363', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 80659114, 'id_str': '80659114', 'name': 'Anthony W', 'screen_name': 'AnthonyW182', 'location': 'Dorset', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 155, 'friends_count': 1094, 'listed_count': 1, 'created_at': 'Wed Oct 07 19:29:34 +0000 2009', 'favourites_count': 55526, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 13512, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1417622640009883648/SeQccm1J_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1417622640009883648/SeQccm1J_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1447490731212517384, 'quoted_status_id_str': '1447490731212517384', 'quoted_status': {'created_at': 'Mon Oct 11 09:14:18 +0000 2021', 'id': 1447490731212517384, 'id_str': '1447490731212517384', 'text': 'Business will struggle to navigate the diminished trading conditions brought on by Brexit, the econ. will take the… https://t.co/zn41qYT6Ai', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/zn41qYT6Ai', 'expanded_url': 'https://twitter.com/i/web/status/1447490731212517384', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1447490429931372545, 'in_reply_to_status_id_str': '1447490429931372545', 'in_reply_to_user_id': 213420029, 'in_reply_to_user_id_str': '213420029', 'in_reply_to_screen_name': 'NashSGC', 'user': {'id': 213420029, 'id_str': '213420029', 'name': 'Sydney Nash', 'screen_name': 'NashSGC', 'location': 'SE25', 'description': 'Former Civil Servant, former UK/EU negotiator, former automotive, former this, that and the other, always Palace - Views my own, RTs not an endorsement', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6721, 'friends_count': 591, 'listed_count': 94, 'created_at': 'Mon Nov 08 21:51:19 +0000 2010', 'favourites_count': 9993, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verifie ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:46 +0000 2021', 'id': 1447540678691524609, 'id_str': '1447540678691524609', 'text': 'RT @DannyMack100: LiZaRdS\n@twk4usa\n@cryillic_\n@0u8up2\n@skipmav \n@FL4DJT\n@USARGB\n@TrumpitC\n@bean8920\n@RacyItalian\n@truth_sniper\n@ItallionTon…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DannyMack100', 'name': 'Danny Mack💯 Everywhere', 'id': 1107894591070572545, 'id_str': '1107894591070572545', 'indices': [3, 16]}, {'screen_name': 'twk4usa', 'name': 'Twk4USA', 'id': 1325803514937872385, 'id_str': '1325803514937872385', 'indices': [26, 34]}, {'screen_name': 'cryillic_', 'name': '♟pawn♟', 'id': 1407520811699765248, 'id_str': '1407520811699765248', 'indices': [35, 45]}, {'screen_name': '0u8up2', 'name': '𝓢𝓲𝓻 𝓓𝓪𝓿𝓮 🧐🎩', 'id': 1041469975293304834, 'id_str': '1041469975293304834', 'indices': [46, 53]}, {'screen_name': 'skipmav', 'name': '🇺🇸🇺🇸🇺🇸🇺🇸', 'id': 309953434, 'id_str': '309953434', 'indices': [54, 62]}, {'screen_name': 'FL4DJT', 'name': '🐠Liz🐠', 'id': 1068648250566213633, 'id_str': '1068648250566213633', 'indices': [64, 71]}, {'screen_name': 'USARGB', 'name': 'USA Warrior', 'id': 1390846102082043905, 'id_str': '1390846102082043905', 'indices': [72, 79]}, {'screen_name': 'TrumpitC', 'name': 'YackNow Founder', 'id': 1012878737044656129, 'id_str': '1012878737044656129', 'indices': [80, 89]}, {'screen_name': 'bean8920', 'name': 'bean🇺🇸🇮🇹', 'id': 1373366725580886016, 'id_str': '1373366725580886016', 'indices': [90, 99]}, {'screen_name': 'RacyItalian', 'name': 'Rαƈყ Sιƈιʅιαɳ™ 🇺🇲🇮🇹 🅳🅾 🅽🅾🆃 🅲🅾🅼🅿🅻🆈', 'id': 1324924608399757312, 'id_str': '1324924608399757312', 'indices': [100, 112]}, {'screen_name': 'truth_sniper', 'name': '🅣🅡🅤🅣🅗_Ş₦łPEŘ ■■■■III%r', 'id': 1276337245394554880, 'id_str': '1276337245394554880', 'indices': [113, 126]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1349721032400261121, 'id_str': '1349721032400261121', 'name': '✨̷̥͎͖̞̅̓̓̀̇̽̕͘ͅ♌️𝔉𝔢𝔩𝔦𝔠𝔦𝔱𝔶♌️✨̷̥͎͖̞̅̓̓̀̇̽̕͘ͅ', 'screen_name': 'N0QuitFe', 'location': 'Everywhere', 'description': 'You must make yourself happy first. THIS IS NOT A DATING APP. I love my country and our Vets, Military, the Blue. 8/9 ❤️🇺🇸', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 9190, 'friends_count': 7831, 'listed_count': 1, 'created_at': 'Thu Jan 14 14:15:22 +0000 2021', 'favourites_count': 19542, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 18482, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1445438123836690443/pC1cFhM-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1445438123836690443/pC1cFhM-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1349721032400261121/1624845680', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Oct 09 03:49:39 +0000 2021', 'id': 1446684258198855682, 'id_str':  ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:46 +0000 2021', 'id': 1447540677978505217, 'id_str': '1447540677978505217', 'text': '@that1autumnleaf Rudu truth 😑', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'that1autumnleaf', 'name': 'Autumn 🍂Top .4%', 'id': 465876210, 'id_str': '465876210', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'cy', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1447540507580801024, 'in_reply_to_status_id_str': '1447540507580801024', 'in_reply_to_user_id': 465876210, 'in_reply_to_user_id_str': '465876210', 'in_reply_to_screen_name': 'that1autumnleaf', 'user': {'id': 1407227958692098048, 'id_str': '1407227958692098048', 'name': 'Oskars Klavins', 'screen_name': 'OKlavins', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Tue Jun 22 06:44:34 +0000 2021', 'favourites_count': 271, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1407228237730701316/7sjKspgN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1407228237730701316/7sjKspgN_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'cy'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 46), id=1447540677978505217, id_str='1447540677978505217', text='@that1autumnleaf Rudu truth 😑', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'that1autumnleaf', 'name': 'Autumn 🍂Top .4%', 'id': 465876210, 'id_str': '465876210', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'cy', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1447540507580801024, in_reply_to_status_id_str='1447540507580801024', in_reply_to_user_id=465876210, in_reply_to_user_id_str='465876210', in_reply_to_screen_name='that1autumnleaf', author=User(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'id': 1407227958692098048, 'id_str': '1407227958692098048', 'name': 'Oskars Klavins', 'screen_name': 'OKlavins', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Tue Jun 22 06:44:34 +0000 2021', 'favourites_count': 271, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1407228237730701316/7sjKspgN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1407228237 ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:46 +0000 2021', 'id': 1447540677856972804, 'id_str': '1447540677856972804', 'text': 'There could be a few reasons for Shanks speaking about Robin…\n\n• He wants to stop Blackbeard having her.\n\n• He know… https://t.co/CKRTejVUSW', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CKRTejVUSW', 'expanded_url': 'https://twitter.com/i/web/status/1447540677856972804', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1447537183028662274, 'in_reply_to_status_id_str': '1447537183028662274', 'in_reply_to_user_id': 834707323499249665, 'in_reply_to_user_id_str': '834707323499249665', 'in_reply_to_screen_name': 'GamingKav', 'user': {'id': 834707323499249665, 'id_str': '834707323499249665', 'name': 'Kav 🎮', 'screen_name': 'GamingKav', 'location': 'Manchester, England', 'description': 'Husband, (step)father & geek. I occasionally upload my gaming exploits to YouTube - I’m rubbish so don’t take my videos seriously, I don’t, I only game for fun.', 'url': 'https://t.co/qo4ikSMvZ5', 'entities': {'url': {'urls': [{'url': 'https://t.co/qo4ikSMvZ5', 'expanded_url': 'https://youtube.com/user/kav82', 'display_url': 'youtube.com/user/kav82', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 85, 'friends_count': 400, 'listed_count': 1, 'created_at': 'Thu Feb 23 10:11:48 +0000 2017', 'favourites_count': 17871, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7046, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/835219316530376704/f-bKm-3-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835219316530376704/f-bKm-3-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/834707323499249665/1487966683', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 46), id=1447540677856972804, id_str='1447540677856972804', text='There could be a few reasons for Shanks speaking about Robin…\n\n• He wants to stop Blackbeard having her.\n\n• He know… https://t.co/CKRTejVUSW', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CKRTejVUSW', 'expanded_url': 'https://twitter.com/i/web/status/1447540677856972804', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1447537183028662274, in_reply_to_status_id_str='1447537183028662274', in_reply_to_user_id=834707323499249665, in_reply_to_user_id_str='834707323499249665', in_reply_to_screen_name='GamingKav', author=User(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'id': 834707323499249665, 'id_str': '834707323499249665', 'name': 'Kav 🎮', 'screen_na ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:45 +0000 2021', 'id': 1447540676107898880, 'id_str': '1447540676107898880', 'text': 'RT @packiarajan: ஒரு அப்பாவி ஏழை தொழிலாளியை அடித்தே கொன்ற திமுக எம்பியின் கொலைபாதக செயலை விட ஒரு மேடையில் பேசிய ஓரிரு வார்த்தைகள் தான் சில…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'packiarajan', 'name': 'Packiarajan.. சே..', 'id': 120649310, 'id_str': '120649310', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'ta', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1045860097405136897, 'id_str': '1045860097405136897', 'name': 'கோடர்', 'screen_name': 'chinnapaluvett1', 'location': '', 'description': 'Tamil. Let’s unite', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1280, 'friends_count': 305, 'listed_count': 0, 'created_at': 'Sat Sep 29 02:17:33 +0000 2018', 'favourites_count': 31202, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 48369, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1436889168366424066/A4Gq3cuh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1436889168366424066/A4Gq3cuh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1045860097405136897/1604710981', 'profile_link_color': '19CF86', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 08:37:54 +0000 2021', 'id': 1447481574660796419, 'id_str': '1447481574660796419', 'text': 'ஒரு அப்பாவி ஏழை தொழிலாளியை அடித்தே கொன்ற திமுக எம்பியின் கொலைபாதக செயலை விட ஒரு மேடையில் பேசிய ஓரிரு வார்த்தைகள் தா… https://t.co/h9EzDEiOqu', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/h9EzDEiOqu', 'expanded_url': 'https://twitter.com/i/web/status/1447481574660796419', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'ta', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 120649310, 'id_str': '120649310', 'name': 'Packiarajan.. சே..', 'screen_name': 'packiarajan', 'location': 'Chennai', 'description': 'Spokesperson, Naam Tamilar Katchi || செய்தித் தொடர்பாளர் நாம் தமிழர் கட்சி., Profession - Managing Director.', 'url': 'https://t.co/76BdA0Q9Qr', 'entities': {'url': {'urls': [{'url': 'https://t.co/76BdA0Q9Qr', 'expanded_url': 'http://www.naamtamilar.org', 'display_url': 'naamtamilar.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 38641, 'friends_count': 836, 'listed_count': 23, 'created_at': 'Sun Mar 07 03:36:02 +0000 2010', 'favourites_count': 15639, 'ut ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:44 +0000 2021', 'id': 1447540671909404673, 'id_str': '1447540671909404673', 'text': 'RT @WalshFreedom: If a candidate can’t tell the truth about the 2020 presidential election, it doesn’t matter where they stand on any other…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'WalshFreedom', 'name': 'Joe Walsh', 'id': 236487888, 'id_str': '236487888', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 863538242, 'id_str': '863538242', 'name': 'Christian Gärtner', 'screen_name': 'Garner1974', 'location': 'Sachsen b.Ansbach, Deutschland', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 75, 'friends_count': 276, 'listed_count': 2, 'created_at': 'Fri Oct 05 19:13:20 +0000 2012', 'favourites_count': 6119, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6844, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1303098021073256449/dQcznjLh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1303098021073256449/dQcznjLh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863538242/1485216375', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 12:01:48 +0000 2021', 'id': 1447532884860997633, 'id_str': '1447532884860997633', 'text': 'If a candidate can’t tell the truth about the 2020 presidential election, it doesn’t matter where they stand on any… https://t.co/DnxHCvkQXA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DnxHCvkQXA', 'expanded_url': 'https://twitter.com/i/web/status/1447532884860997633', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 236487888, 'id_str': '236487888', 'name': 'Joe Walsh', 'screen_name': 'WalshFreedom', 'location': 'Chicago', 'description': 'Former Candidate for President. Former Congressman. Author, “F*ck Silence.” Patriot, Husband, Father, Brother, Son. #BeBrave', 'url': 'https://t.co/0XbXsrl6JI', 'entities': {'url': {'urls': [{'url': 'https://t.co/0XbXsrl6JI', 'expanded_url': 'http://fsilencepodcast.com/', 'display_url': 'fsilencepodcast.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 346554, 'friends_count': 26844, 'listed_count': 2940, 'created_at': 'Mon Jan 10 18:11:53 +0000 2011', 'favourites_count': 9772, 'utc_offset ...
# ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:23 +0000 2021', 'id': 1447540583799611398, 'id_str': '1447540583799611398', 'text': '@JohnTheWhite1 @joolsthebass You mean the truth that Bowelstrek took and eternity to answer Jay’s request to set a date?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JohnTheWhite1', 'name': 'John The White', 'id': 1049659390331117568, 'id_str': '1049659390331117568', 'indices': [0, 14]}, {'screen_name': 'joolsthebass', 'name': 'jools the bass', 'id': 866017826, 'id_str': '866017826', 'indices': [15, 28]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1447479418868441091, 'in_reply_to_status_id_str': '1447479418868441091', 'in_reply_to_user_id': 1049659390331117568, 'in_reply_to_user_id_str': '1049659390331117568', 'in_reply_to_screen_name': 'JohnTheWhite1', 'user': {'id': 1184238482560094208, 'id_str': '1184238482560094208', 'name': 'Caitlin Carstairs 💗🏳️\u200d🌈🏳️\u200d⚧️', 'screen_name': 'KitKatisWeird7', 'location': 'England, United Kingdom', 'description': 'Carstairs Supremacy / Metroid and Zelda fan / Shadowhunters / Marvel / Star Wars / Sitcoms / Lost Media. She/Her', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 442, 'friends_count': 976, 'listed_count': 4, 'created_at': 'Tue Oct 15 22:43:59 +0000 2019', 'favourites_count': 67087, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 27640, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1409710115587072005/kfIIYz-0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1409710115587072005/kfIIYz-0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1184238482560094208/1624936058', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 23), id=1447540583799611398, id_str='1447540583799611398', text='@JohnTheWhite1 @joolsthebass You mean the truth that Bowelstrek took and eternity to answer Jay’s request to set a date?', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JohnTheWhite1', 'name': 'John The White', 'id': 1049659390331117568, 'id_str': '1049659390331117568', 'indices': [0, 14]}, {'screen_name': 'joolsthebass', 'name': 'jools the bass', 'id': 866017826, 'id_str': '866017826', 'indices': [15, 28]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1447479418868441091, in_reply_to_status_id_str='1447479418868441091', in_reply_to_user_id=1049659390331117568, in_reply_to_user_id_str='1049659390331117568', in_reply_to_screen_name='JohnTheWhite1', author=User(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'id': 1184238482560094208, 'id_str': '1184238482560094208', 'name': 'Caitlin Carstairs 💗🏳️\u200d🌈🏳️\u200d⚧️', 'screen_name': 'KitKatisWeird ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:23 +0000 2021', 'id': 1447540582910414856, 'id_str': '1447540582910414856', 'text': 'truth', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 743426597038886912, 'id_str': '743426597038886912', 'name': 'eridan ampora', 'screen_name': 'eridanbot', 'location': '', 'description': 'a bot for evveryones favvorite sea dwweller that posts kanye twweets evvery 30 minutes', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 30, 'friends_count': 0, 'listed_count': 2, 'created_at': 'Thu Jun 16 12:54:47 +0000 2016', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 81019, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/743426886827540481/smU9Tzko_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/743426886827540481/smU9Tzko_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/743426597038886912/1466082923', 'profile_link_color': '6A006A', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 11, 12, 32, 23), id=1447540582910414856, id_str='1447540582910414856', text='truth', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Cheap Bots, Done Quick!', source_url='https://cheapbotsdonequick.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'id': 743426597038886912, 'id_str': '743426597038886912', 'name': 'eridan ampora', 'screen_name': 'eridanbot', 'location': '', 'description': 'a bot for evveryones favvorite sea dwweller that posts kanye twweets evvery 30 minutes', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 30, 'friends_count': 0, 'listed_count': 2, 'created_at': 'Thu Jun 16 12:54:47 +0000 2016', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 81019, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/743426886827540481/smU9Tzko_normal.jpg', 'profile_image_url_https': 'https: ...
#  Status(_api=<tweepy.api.API object at 0x1121c79d0>, _json={'created_at': 'Mon Oct 11 12:32:23 +0000 2021', 'id': 1447540581719330828, 'id_str': '1447540581719330828', 'text': 'RT @mapuche_girl: Can #nft do good to this world?  Can #nftcommunity and #blockchain #technology help justice be done?  i think they can!…', 'truncated': False, 'entities': {'hashtags': [{'text': 'nft', 'indices': [22, 26]}, {'text': 'nftcommunity', 'indices': [55, 68]}, {'text': 'blockchain', 'indices': [73, 84]}, {'text': 'technology', 'indices': [85, 96]}], 'symbols': [], 'user_mentions': [{'screen_name': 'mapuche_girl', 'name': 'Irma Vidal', 'id': 1433017434898841601, 'id_str': '1433017434898841601', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1420835323458818050, 'id_str': '1420835323458818050', 'name': 'PowerNFT | Promoter', 'screen_name': 'PowerToken3', 'location': '', 'description': "DM for promotion 💌\nLet's grow together🚀\n#NFTPromoter #NFTs #NFTCollector #NFTGiveaway #NFTLovers #CryptoMarket #NFTCollectors #PowerPromotion", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2511, 'friends_count': 132, 'listed_count': 8, 'created_at': 'Thu Jul 29 19:55:24 +0000 2021', 'favourites_count': 6348, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1334, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1436424545624338441/yGqxklPu_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1436424545624338441/yGqxklPu_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1420835323458818050/1630271167', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Oct 07 11:56:00 +0000 2021', 'id': 1446081876784041992, 'id_str': '1446081876784041992', 'text': 'Can #nft do good to this world?  Can #nftcommunity and #blockchain #technology help justice be done?  i think they… https://t.co/wwI49hnymR', 'truncated': True, 'entities': {'hashtags': [{'text': 'nft', 'indices': [4, 8]}, {'text': 'nftcommunity', 'indices': [37, 50]}, {'text': 'blockchain', 'indices': [55, 66]}, {'text': 'technology', 'indices': [67, 78]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/wwI49hnymR', 'expanded_url': 'https://twitter.com/i/web/status/1446081876784041992', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1433017434898841601, 'id_str': '1433017434898841601', 'name': 'Irma Vidal', 'screen_name': 'mapuche_girl', 'location': 'Central Macedonia, Greece', 'description': '#latingirl, #future #nutritionist, #cannabissociety, #NFTcollector, #cryp ...

# %%
# from https://stackoverflow.com/questions/47925828/how-to-create-a-pandas-dataframe-using-tweepy
# hide this function in the notebook
my_list_of_dicts = []
for each_json_tweet in tweets:
    my_list_of_dicts.append(each_json_tweet._json)

with open('tweet_json.txt', 'w') as file:
        file.write(json.dumps(my_list_of_dicts, indent=4))    

my_demo_list = []
with open('tweet_json.txt', encoding='utf-8') as json_file:  
    all_data = json.load(json_file)
    print(all_data)
    for each_dictionary in all_data:
        tweet_id = each_dictionary['id']
        screen_name = each_dictionary['screen_name']
        text = each_dictionary['text']
        favorite_count = each_dictionary['favorite_count']
        retweet_count = each_dictionary['retweet_count']
        created_at = each_dictionary['created_at']
        my_demo_list.append({'tweet_id': str(tweet_id),
                             'screen_name': str(screen_name),
                             'text': str(text),
                             'favorite_count': int(favorite_count),
                             'retweet_count': int(retweet_count),
                             'created_at': created_at,
                            })
        #print(my_demo_list)
        tweet_df = pd.DataFrame(my_demo_list, columns = 
                                  ['screen_name', 'tweet_id', 'text', 
                                   'favorite_count', 'retweet_count', 
                                   'created_at'])
# Out:
# [{'created_at': 'Mon Oct 11 12:32:47 +0000 2021', 'id': 1447540683527626752, 'id_str': '1447540683527626752', 'text': 'RT @IrrawaddyNews: Myanmar Under the Tatmadaw: Much Has Changed Since 1988\nhttps://t.co/yTyfwHMr8D\n\n#WhatsHappeningInMyanmar\n--------------…', 'truncated': False, 'entities': {'hashtags': [{'text': 'WhatsHappeningInMyanmar', 'indices': [100, 124]}], 'symbols': [], 'user_mentions': [{'screen_name': 'IrrawaddyNews', 'name': 'The Irrawaddy (Eng)', 'id': 57289662, 'id_str': '57289662', 'indices': [3, 17]}], 'urls': [{'url': 'https://t.co/yTyfwHMr8D', 'expanded_url': 'https://bit.ly/3mL02vU', 'display_url': 'bit.ly/3mL02vU', 'indices': [75, 98]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1348531359690620930, 'id_str': '1348531359690620930', 'name': 'アウンティハミン', 'screen_name': 'BOUQUET_BUCKET', 'location': 'United States', 'description': 'Sometimes you have to pick the gun up to put the gun down! Revolution never go backward!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 243, 'friends_count': 114, 'listed_count': 0, 'created_at': 'Mon Jan 11 07:25:23 +0000 2021', 'favourites_count': 26152, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 68636, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1435140483609620481/owhFuElx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1435140483609620481/owhFuElx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1348531359690620930/1630689798', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 10:27:26 +0000 2021', 'id': 1447509138456514563, 'id_str': '1447509138456514563', 'text': 'Myanmar Under the Tatmadaw: Much Has Changed Since 1988\nhttps://t.co/yTyfwHMr8D\n\n#WhatsHappeningInMyanmar\n---------… https://t.co/6sc8y5uvuU', 'truncated': True, 'entities': {'hashtags': [{'text': 'WhatsHappeningInMyanmar', 'indices': [81, 105]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/yTyfwHMr8D', 'expanded_url': 'https://bit.ly/3mL02vU', 'display_url': 'bit.ly/3mL02vU', 'indices': [56, 79]}, {'url': 'https://t.co/6sc8y5uvuU', 'expanded_url': 'https://twitter.com/i/web/status/1447509138456514563', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 57289662, 'id_str': '57289662', 'name': 'The Irrawaddy (Eng)', 'screen_name': 'IrrawaddyNews', 'location': 'Myanmar', 'description': 'Covering Burma & Southeast Asia', 'url': 'https://t.co/yZYCx4G4Vf', 'entities': {'url': {'urls': [{'url': 'https://t.co/yZYCx4G4Vf', 'expanded_url': 'http://www.irrawaddy.com', 'display_url': ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c1af963fa141> in <module>
#      14     for each_dictionary in all_data:
#      15         tweet_id = each_dictionary['id']
# ---> 16         screen_name = each_dictionary['screen_name']
#      17         text = each_dictionary['text']
#      18         favorite_count = each_dictionary['favorite_count']
#
# KeyError: 'screen_name'

# %%
tweet_df.head()
# Out:
#    screen_name             tweet_id  \
# 0          NaN  1447540683527626752
# 1          NaN  1447540682994987009
# 2          NaN  1447540682378285062
# 3          NaN  1447540682214739971
# 4          NaN  1447540680797085705
#
#                                                 text  favorite_count  \
# 0  RT @IrrawaddyNews: Myanmar Under the Tatmadaw:...               0
# 1  RT @RepAdamSchiff: It’s a simple question with...               0
# 2  @HoldthisLfam69 @EmilScottie @ShibaArchives In...               0
# 3  RT @bedfordyid: "The rich, the famous and the ...               0
# 4  @prageru Morning! Truth still matters! So don'...               0
#
#    retweet_count                      created_at
# 0            118  Mon Oct 11 12:32:47 +0000 2021
# 1           7278  Mon Oct 11 12:32:47 +0000 2021
# 2              0  Mon Oct 11 12:32:47 +0000 2021
# 3              1  Mon Oct 11 12:32:47 +0000 2021
# 4              0  Mon Oct 11 12:32:46 +0000 2021

# %%
json_data = [r._json for r in tweets]

df = pd.json_normalize(json_data)

# %%
# graph = Graph.DictList(
#           vertices=nodes.to_dict('records'),
#           edges=relations.to_dict('records'),
#           directed=True,
#           vertex_name_attr='userid',
#           edge_foreign_keys=('tweets', 'text', 'screen_name', 'status_id'));
