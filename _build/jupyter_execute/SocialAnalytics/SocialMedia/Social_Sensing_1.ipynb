# %% [markdown]
# # Social Sensing 1

# %% [markdown]
# There are a lot of social, cultural and other datasets out there on the web. We have already learned how to extract data from web sites directly. Many data items can also be accessed via a so-called API (Application Programming Interface). You can think of an API as a window through which you have access to remotely stored data rather than web pages. Often access to these APIs is limited by some kind of registration key you have to use to open that window. Before you proceed with this lesson, please register now for the two services we will work with today. The first one is the US data.gov site, which contains all kinds of datasets – mostly by the US government. You can register for a key under https://api.data.gov/signup. The second online service is Twitter and does not need an introduction. You can sign up for the several keys we need from Twitter at https://apps.twitter.com/. Here you can create an app that gives you the key and consumer secret.

# %% [markdown]
# ## requests to call api in python
# To call an api in python and access data from a website we need the requests package first, download and import it.

# %%
import requests

# %% [markdown]
# Now, we want to play with electricity rates and associated coordinate information for US locations by looking them up on data.gov. Let’s first define a place we are interested in. Because we want to use it again later, let’s assign address_ex = ‘1600 Amphitheatre Parkway, Mountain View, CA’. Do you know who ‘lives’ at this address?

# %%
from ipynb.fs.full.keys import *

address_x = '1600 Amphitheatre Parkway, Mountain View, CA'
api_key = gov_key
url = 'https://developer.nrel.gov/api/utility_rates/v3.json'

# %% [markdown]
# Requests has a get function that allows you to read/get data from remote sites.

# %%
params = dict(api_key=api_key, address=address_x)
req_1 = requests.get(url, params=params)

# %% [markdown]
# Finally, we can use another requests function to access the results or the actual text of the API call. Type in result = request.text

# %%
result = req_1.text
result
# Out:
# '{"inputs":{"address":"1600 Amphitheatre Parkway, Mountain View, CA"},"errors":[],"warnings":[],"version":"3.1.0","metadata":{"sources":["Ventyx Research (2012)"]},"outputs":{"company_id":"14328","utility_name":"Pacific Gas \\u0026 Electric Co","utility_info":[{"company_id":"14328","utility_name":"Pacific Gas \\u0026 Electric Co"}],"commercial":0.1408,"industrial":0.0898,"residential":0.1559}}'

# %% [markdown]
# Unfortunately, result is a rather complex list. To get, for instance, the utility name, we have to first convert the response into json data so we can access it more easily.

# %%
request_data = req_1.json()
print(request_data)
# Out:
# {'inputs': {'address': '1600 Amphitheatre Parkway, Mountain View, CA'}, 'errors': [], 'warnings': [], 'version': '3.1.0', 'metadata': {'sources': ['Ventyx Research (2012)']}, 'outputs': {'company_id': '14328', 'utility_name': 'Pacific Gas & Electric Co', 'utility_info': [{'company_id': '14328', 'utility_name': 'Pacific Gas & Electric Co'}], 'commercial': 0.1408, 'industrial': 0.0898, 'residential': 0.1559}}

# %% [markdown]
# We can then access parts of it by seeing it as a dictionary, to get the utitility name we need to first access outputs and then access utiltiy_name

# %%
request_data['outputs']['utility_name']
# Out:
# 'Pacific Gas & Electric Co'

# %% [markdown]
# To get the residential electricity rate at the address, look for outputs and then residential.

# %%
request_data['outputs']['residential']
# Out:
# 0.1559

# %% [markdown]
# Google has many useful APIs. For instance, maps.googleapis.com returns the geo-locations for addresses. Again, access is restricted but you can run a few requests without a key. Let’s look up the geo-location of our address_ex, which is of course the location of the Googleplex, Google’s HQ. Again, get the location information
#
# --> An API key is needed which costs money

# %%
params = dict(address = address_x, key = 'AIzaSyDQ8DkiK3SV9V2TpwekTwHmTEXYvuHNEP8')
url = 'https://maps.googleapis.com/maps/api/geocode/json?'
req_2 = requests.get(url=url, params=params)

# %%
req_2.text
# Out:
# '{\n   "error_message" : "This API project is not authorized to use this API.",\n   "results" : [],\n   "status" : "REQUEST_DENIED"\n}\n'

# %% [markdown]
# --> It says I'm not autohorized to use this API
#
#
# We are interested in the latitude and longitude of the Googleplex. Let's first convert it to readable data again

# %% [markdown]
# The longitude is available if we change 'lat' to 'lng'

# %% [markdown]
# You could now use http://www.latlong.net/Show-Latitude-Longitude.html to map these longitude and latitude and would find the Googleplex.

# %% [markdown]
# We have just worked through simple API requests that got us locations. More interesting will be to access social media applications like Twitter and Facebook. We can also get their data through APIs. Twitter is especially popular.

# %% [markdown]
# In python there is a library that makes accessing Twitter data simple. Download and import tweepy.

# %%
import tweepy

# %%
consumer_key = twit_key
consumer_secret = twit_secr
access_token = twit_token

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %% [markdown]
# We are connected to Twitter and can run queries. Let’s get Barack Obama's timeline and his first tweet first

# %%
obama = api.get_user(screen_name = 'BarackObama')
ob_id = obama.id
tweets = api.user_timeline('BarackObama', count=100)
first_tweet = tweets[0]

# %% [markdown]
# Let's check the first tweet of the dataset by typing first_tweet.text

# %%
first_tweet.text
# Out:
# 'On Wednesday, I’ll join activists, community leaders, and young people from the @MBK_Alliance for a conversation ab… https://t.co/ox5MMycHmd'

# %% [markdown]
# To see all the attributes of a tweet, simply type tweets[0], but for now we only want to check the date using first_tweet.created_at

# %%
first_tweet.created_at
# Out:
# datetime.datetime(2021, 5, 24, 20, 5, 4)

# %% [markdown]
# Could we find a way to plot Obama his twitter activity?

# %%
dates = []
for tweet in tweets:
    date = tweet.created_at
    date = date.date()
    dates.append(date)
dates
# Out:
# [datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 12),
#  datetime.date(2021, 5, 10),
#  datetime.date(2021, 5, 9),
#  datetime.date(2021, 5, 8),
#  datetime.date(2021, 5, 8),
#  datetime.date(2021, 5, 8),
#  datetime.date(2021, 5, 6),
#  datetime.date(2021, 5, 6),
#  datetime.date(2021, 4, 30),
#  datetime.date(2021, 4, 30),
#  datetime.date(2021, 4, 29),
#  datetime.date(2021, 4, 29),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 24),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 18),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 14),
#  datetime.date(2021, 4, 14),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 4, 9),
#  datetime.date(2021, 4, 6),
#  datetime.date(2021, 4, 5),
#  datetime.date(2021, 4, 5),
#  datetime.date(2021, 4, 5),
#  datetime.date(2021, 4, 4),
#  datetime.date(2021, 4, 3),
#  datetime.date(2021, 3, 30),
#  datetime.date(2021, 3, 30),
#  datetime.date(2021, 3, 29),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 15),
#  datetime.date(2021, 3, 15),
#  datetime.date(2021, 3, 15),
#  datetime.date(2021, 3, 12),
#  datetime.date(2021, 3, 11),
#  datetime.date(2021, 3, 8),
#  datetime.date(2021, 3, 7),
#  datetime.date(2021, 3, 6),
#  datetime.date(2021, 3, 6),
#  datetime.date(2021, 3, 6),
#  datetime.date(2021, 3, 5),
#  datetime.date(2021, 3, 4),
#  datetime.date(2021, 3, 4),
#  datetime.date(2021, 3, 2),
#  datetime.date(2021, 3, 2),
#  datetime.date(2021, 3, 1),
#  datetime.date(2021, 3, 1),
#  datetime.date(2021, 2, 27),
#  datetime.date(2021, 2, 27),
#  datetime.date(2021, 2, 26),
#  datetime.date(2021, 2, 25),
#  datetime.date(2021, 2, 24),
#  datetime.date(2021, 2, 24),
#  datetime.date(2021, 2, 24),
#  datetime.date(2021, 2, 22),
#  datetime.date(2021, 2, 22),
#  datetime.date(2021, 2, 19),
#  datetime.date(2021, 2, 18),
#  datetime.date(2021, 2, 18),
#  datetime.date(2021, 2, 17),
#  datetime.date(2021, 2, 15),
#  datetime.date(2021, 2, 14),
#  datetime.date(2021, 2, 12),
#  datetime.date(2021, 2, 9),
#  datetime.date(2021, 2, 5),
#  datetime.date(2021, 2, 3),
#  datetime.date(2021, 2, 2),
#  datetime.date(2021, 1, 31),
#  datetime.date(2021, 1, 29),
#  datetime.date(2021, 1, 29),
#  datetime.date(2021, 1, 27)]

# %%
from collections import Counter
import matplotlib.pyplot as plt

counts = Counter(dates)
plt.bar(counts.keys(), counts.values())
# Out:
# <BarContainer object of 61 artists>

# %% [markdown]
# Let’s move on from Obama. In order to access my own Twitter favourites, please type in api.favorites('tobias_blanke')

# %%
favorites = api.favorites('tobias_blanke')
favorite = favorites[0] 
favorite.text
# Out:
# 'The news is official: I received an @ERC_Research advanced grant for a longue-durée social history of infrastructur… https://t.co/j4DIrkkCuB'

# %% [markdown]
# So far, so good. Of course, these requests were quite simple. So, let’s try something more complicated. We start with first a look at the retweet structures and then a typical content analysis in Twitter. Tweets are little pieces of texts with lots of metadata attached to them (https://en.wikipedia.org/wiki/Twitter). So, it is not surprising that many people try and run text analysis on the content of tweets. Let’s start with that.

# %% [markdown]
# The first step is to search Twitter for something of interest by running api.search(q=‘#kcl’, count = 10). This search will look for the most recent tweets (count=10) with the hashtag kcl.

# %%
kcl_tweets = api.search(q='#kcl', count =10)

# %% [markdown]
# As we can see each tweet has an id and a lot of other metadata attached to it such as retweets, locations, etc. Did you know that you produce so much information with each tweet?
#
# There are a lot of things we can do with tweets and their metadata. Have a look at the documentation of the package or the many examples online. A quick example would be to return retweets. The first step is to find them. Looking at the metadata of each tweet in kcl_tweets, there are two relevant fields with retweet_count and retweeted. With retweet_count, we can check whether a tweet has been retweeted (retweet_count > 0), while retweeted tells us whether a tweet was a retweet itself. We want to find only those tweets that have not been retweets (retweeted == False) but are not a retweet. So, please select those kcl_tweets that have been retweeted.

# %%
retweeted_kcl_tweets = []
for kcl_tweet in kcl_tweets:
    if kcl_tweet.retweeted == False and kcl_tweet.retweet_count > 0:
        retweeted_kcl_tweets.append(kcl_tweet)
        
retweeted_kcl_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Tue May 25 11:36:26 +0000 2021', 'id': 1397154587279339521, 'id_str': '1397154587279339521', 'text': 'RT @KingsMLC: Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that you can use…', 'truncated': False, 'entities': {'hashtags': [{'text': 'WordOfTheDay', 'indices': [18, 31]}, {'text': 'Dutch', 'indices': [38, 44]}], 'symbols': [], 'user_mentions': [{'screen_name': 'KingsMLC', 'name': "Modern Language Centre, King's College London", 'id': 948605709607952384, 'id_str': '948605709607952384', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 762192800, 'id_str': '762192800', 'name': 'Tony Thorne', 'screen_name': 'tonythorne007', 'location': 'London, England', 'description': "Recording and commenting on slang, new language, lifestyle innovations. Writer and lexicographer. Language Consultant at King's College London.", 'url': 'https://t.co/0KktruyeGZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/0KktruyeGZ', 'expanded_url': 'https://language-and-innovation.com/', 'display_url': 'language-and-innovation.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4579, 'friends_count': 3149, 'listed_count': 90, 'created_at': 'Thu Aug 16 19:38:45 +0000 2012', 'favourites_count': 163598, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 52155, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/583169348900016129/8EzuxOnp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/583169348900016129/8EzuxOnp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/762192800/1399561828', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 25 11:33:02 +0000 2021', 'id': 1397153734187180035, 'id_str': '1397153734187180035', 'text': 'Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that y… https://t.co/hzITUWzKqr', 'truncated': True, 'entities': {'hashtags': [{'text': 'WordOfTheDay', 'indices': [4, 17]}, {'text': 'Dutch', 'indices': [24, 30]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hzITUWzKqr', 'expanded_url': 'https://twitter.com/i/web/status/1397153734187180035', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 948605709607952384, 'id_str': '948605709607952384', 'name': "Modern Language Centre, King's College London", 'screen_name': 'KingsMLC', 'location': ...
#  Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Tue May 25 11:33:02 +0000 2021', 'id': 1397153734187180035, 'id_str': '1397153734187180035', 'text': 'Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that y… https://t.co/hzITUWzKqr', 'truncated': True, 'entities': {'hashtags': [{'text': 'WordOfTheDay', 'indices': [4, 17]}, {'text': 'Dutch', 'indices': [24, 30]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hzITUWzKqr', 'expanded_url': 'https://twitter.com/i/web/status/1397153734187180035', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 948605709607952384, 'id_str': '948605709607952384', 'name': "Modern Language Centre, King's College London", 'screen_name': 'KingsMLC', 'location': 'London, England', 'description': "The Modern Language Centre at King's College London provides expert language tuition online and in the heart of London and is open to all.", 'url': 'https://t.co/lpazAe5AfT', 'entities': {'url': {'urls': [{'url': 'https://t.co/lpazAe5AfT', 'expanded_url': 'http://www.kcl.ac.uk/mlc', 'display_url': 'kcl.ac.uk/mlc', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 663, 'friends_count': 139, 'listed_count': 4, 'created_at': 'Wed Jan 03 17:23:20 +0000 2018', 'favourites_count': 223, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1081, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1159054729441415169/RElwoyrU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159054729441415169/RElwoyrU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/948605709607952384/1613563550', 'profile_link_color': '19CF86', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 25, 11, 33, 2), id=1397153734187180035, id_str='1397153734187180035', text='Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that y… https://t.co/hzITUWzKqr', truncated=True, entities={'hashtags': [{'text': 'WordOfTheDay', 'indices': [4, 17]}, {'text': 'Dutch', 'indices': [24, 30]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hzITUWzKqr', 'expanded_url': 'https://twitter.com/i/web/status/1397153734187180035', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Buffer', source_url='https://buffer.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x10a462eb0>, _json ...
#  Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Mon May 24 17:44:45 +0000 2021', 'id': 1396884891317460992, 'id_str': '1396884891317460992', 'text': 'RT @AnisahEbrahimj1: Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If yo…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Zoom', 'indices': [38, 43]}, {'text': 'teams', 'indices': [63, 69]}, {'text': 'videocalls', 'indices': [121, 132]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AnisahEbrahimj1', 'name': 'Anisah Ebrahimjee', 'id': 1355180102406041600, 'id_str': '1355180102406041600', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 66411637, 'id_str': '66411637', 'name': 'Simon Riches', 'screen_name': 'sjriches', 'location': 'London', 'description': 'Clinical psychologist, academic tutor @KingsIoPPN  @MaudsleyNHS | Visiting fellow @LSBU | PhD in philosophy @UCLPhilosophy  | Views my own', 'url': 'https://t.co/DKlnOhy3wD', 'entities': {'url': {'urls': [{'url': 'https://t.co/DKlnOhy3wD', 'expanded_url': 'https://kcl.academia.edu/SimonRiches', 'display_url': 'kcl.academia.edu/SimonRiches', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4743, 'friends_count': 5210, 'listed_count': 185, 'created_at': 'Mon Aug 17 17:02:12 +0000 2009', 'favourites_count': 24495, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8358, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000374137512/d845bf30d61d773d97c17cd28dca42d2_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000374137512/d845bf30d61d773d97c17cd28dca42d2_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/66411637/1377684260', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 24 17:32:16 +0000 2021', 'id': 1396881747644764161, 'id_str': '1396881747644764161', 'text': 'Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If… https://t.co/W0BxLiNxeG', 'truncated': True, 'entities': {'hashtags': [{'text': 'Zoom', 'indices': [17, 22]}, {'text': 'teams', 'indices': [42, 48]}, {'text': 'videocalls', 'indices': [100, 111]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W0BxLiNxeG', 'expanded_url': 'https://twitter.com/i/web/status/1396881747644764161', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1355180102406041600, 'i ...
#  Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Mon May 24 17:32:16 +0000 2021', 'id': 1396881747644764161, 'id_str': '1396881747644764161', 'text': 'Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If… https://t.co/W0BxLiNxeG', 'truncated': True, 'entities': {'hashtags': [{'text': 'Zoom', 'indices': [17, 22]}, {'text': 'teams', 'indices': [42, 48]}, {'text': 'videocalls', 'indices': [100, 111]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W0BxLiNxeG', 'expanded_url': 'https://twitter.com/i/web/status/1396881747644764161', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1355180102406041600, 'id_str': '1355180102406041600', 'name': 'Anisah Ebrahimjee', 'screen_name': 'AnisahEbrahimj1', 'location': '', 'description': 'Clinical Psychology Trainee. @KingsDClinPsy @MaudsleyNHS @KingsIoPPN \nSecret Chef. Loves from the heart.', 'url': 'https://t.co/gZMrjRaYHK', 'entities': {'url': {'urls': [{'url': 'https://t.co/gZMrjRaYHK', 'expanded_url': 'https://kclbs.eu.qualtrics.com/jfe/form/SV_dg06wZ3KLoQ5FD7', 'display_url': 'kclbs.eu.qualtrics.com/jfe/form/SV_dg…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 166, 'friends_count': 636, 'listed_count': 0, 'created_at': 'Fri Jan 29 15:45:06 +0000 2021', 'favourites_count': 188, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 148, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1355304355105275911/hUg0dDGX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1355304355105275911/hUg0dDGX_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 24, 17, 32, 16), id=1396881747644764161, id_str='1396881747644764161', text='Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If… https://t.co/W0BxLiNxeG', truncated=True, entities={'hashtags': [{'text': 'Zoom', 'indices': [17, 22]}, {'text': 'teams', 'indices': [42, 48]}, {'text': 'videocalls', 'indices': [100, 111]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W0BxLiNxeG', 'expanded_url': 'https://twitter.com/i/web/status/1396881747644764161', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'id': 1355180102406041600, 'id_str': '1355180102406041600', 'name': 'Anisah  ...
#  Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Sun May 23 11:35:33 +0000 2021', 'id': 1396429591577698309, 'id_str': '1396429591577698309', 'text': 'RT @KingsMLC: Our #WordOfTheDay is in #French.  Did you know the origin of this phrase? #KCL #MLC #LearnLanguages https://t.co/EXfXP9FViv', 'truncated': False, 'entities': {'hashtags': [{'text': 'WordOfTheDay', 'indices': [18, 31]}, {'text': 'French', 'indices': [38, 45]}, {'text': 'KCL', 'indices': [88, 92]}, {'text': 'MLC', 'indices': [93, 97]}, {'text': 'LearnLanguages', 'indices': [98, 113]}], 'symbols': [], 'user_mentions': [{'screen_name': 'KingsMLC', 'name': "Modern Language Centre, King's College London", 'id': 948605709607952384, 'id_str': '948605709607952384', 'indices': [3, 12]}], 'urls': [], 'media': [{'id': 1396428959760453633, 'id_str': '1396428959760453633', 'indices': [114, 137], 'media_url': 'http://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'url': 'https://t.co/EXfXP9FViv', 'display_url': 'pic.twitter.com/EXfXP9FViv', 'expanded_url': 'https://twitter.com/KingsMLC/status/1396428965254995969/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}}, 'source_status_id': 1396428965254995969, 'source_status_id_str': '1396428965254995969', 'source_user_id': 948605709607952384, 'source_user_id_str': '948605709607952384'}]}, 'extended_entities': {'media': [{'id': 1396428959760453633, 'id_str': '1396428959760453633', 'indices': [114, 137], 'media_url': 'http://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'url': 'https://t.co/EXfXP9FViv', 'display_url': 'pic.twitter.com/EXfXP9FViv', 'expanded_url': 'https://twitter.com/KingsMLC/status/1396428965254995969/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}}, 'source_status_id': 1396428965254995969, 'source_status_id_str': '1396428965254995969', 'source_user_id': 948605709607952384, 'source_user_id_str': '948605709607952384'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2808810912, 'id_str': '2808810912', 'name': 'Josh Koehn 柯恩华', 'screen_name': 'KoehnJosh', 'location': 'California ', 'description': '我很喜欢学语言。Me gusto aprender idiomas. I enjoy languages.🏳️\u200d🌈( 🇧🇷🥋student)..🇨🇳Sinophile/Sinologist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 194, 'friends_count': 1727, 'listed_count': 2, 'created_at': 'Sun Sep 14 06:01:55 +0000 2014', 'favourites_count': 9270, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4906, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1391298066280378372/fYFPr90i_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1391298066280378372/fYFPr90i_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2808810912/1609143139', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_ ...
#  Status(_api=<tweepy.api.API object at 0x10a462eb0>, _json={'created_at': 'Sun May 23 11:33:04 +0000 2021', 'id': 1396428965254995969, 'id_str': '1396428965254995969', 'text': 'Our #WordOfTheDay is in #French.  Did you know the origin of this phrase? #KCL #MLC #LearnLanguages https://t.co/EXfXP9FViv', 'truncated': False, 'entities': {'hashtags': [{'text': 'WordOfTheDay', 'indices': [4, 17]}, {'text': 'French', 'indices': [24, 31]}, {'text': 'KCL', 'indices': [74, 78]}, {'text': 'MLC', 'indices': [79, 83]}, {'text': 'LearnLanguages', 'indices': [84, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1396428959760453633, 'id_str': '1396428959760453633', 'indices': [100, 123], 'media_url': 'http://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'url': 'https://t.co/EXfXP9FViv', 'display_url': 'pic.twitter.com/EXfXP9FViv', 'expanded_url': 'https://twitter.com/KingsMLC/status/1396428965254995969/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1396428959760453633, 'id_str': '1396428959760453633', 'indices': [100, 123], 'media_url': 'http://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E2EcvYSXEAEwmND.jpg', 'url': 'https://t.co/EXfXP9FViv', 'display_url': 'pic.twitter.com/EXfXP9FViv', 'expanded_url': 'https://twitter.com/KingsMLC/status/1396428965254995969/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 948605709607952384, 'id_str': '948605709607952384', 'name': "Modern Language Centre, King's College London", 'screen_name': 'KingsMLC', 'location': 'London, England', 'description': "The Modern Language Centre at King's College London provides expert language tuition online and in the heart of London and is open to all.", 'url': 'https://t.co/lpazAe5AfT', 'entities': {'url': {'urls': [{'url': 'https://t.co/lpazAe5AfT', 'expanded_url': 'http://www.kcl.ac.uk/mlc', 'display_url': 'kcl.ac.uk/mlc', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 663, 'friends_count': 139, 'listed_count': 4, 'created_at': 'Wed Jan 03 17:23:20 +0000 2018', 'favourites_count': 223, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1081, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1159054729441415169/RElwoyrU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159054729441415169/RElwoyrU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/948605709607952384/1613563550', 'profile_link_color': '19CF86', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type':  ...

# %% [markdown]
# As promised, we would like to run some simple content analysis with the text in the tweets. We will produce a simple word cloud. But before we can do this we need to first create a corpus from the tweets, the same as we did with the speeches in the Text assignment.
# Let's first extract the text from the kcl_tweets.

# %%
tweet_text = []
for t in kcl_tweets:
    text = t.text
    tweet_text.append(text)

# %%
import nltk
from nltk.tokenize import word_tokenize

strings = ''.join(tweet_text)
corpus = word_tokenize(strings)
corpus = [word.replace(" ", "") for word in corpus]
corpus = [word.lower() for word in corpus if word.isalpha()]

from nltk.corpus import stopwords
stopwords = list(stopwords.words('english'))
corpus = [word for word in corpus if word not in stopwords]

# %%
from wordcloud import WordCloud


wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',  
                min_font_size = 10).generate(str(corpus)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# Hmmm https shows up there pretty big, let's check if everything went alright.
# Print the tweets that we just added to the corpus.

# %%
tweet = tweet_text[0]
print(tweet)
# Out:
# Intermittent Fasting in mice demonstrably more effective at promoting long term memory retention #KCL… https://t.co/cMWSeziaGw

# %% [markdown]
# As we can see there is a link to the tweet in each text, we should have removed that first. We can use regular expressions for this.

# %%
import re
tweet = re.sub(r'http\S+', '', tweet)
print(tweet)
# Out:
# Intermittent Fasting in mice demonstrably more effective at promoting long term memory retention #KCL…

# %%
cleaned_tweets = []
for tweet in tweet_text:
    tweet = re.sub(r'http\S+', '', tweet) 
    cleaned_tweets.append(tweet)

cleaned_tweets
# Out:
# ['Intermittent Fasting in mice demonstrably more effective at promoting long term memory retention #KCL… ',
#  'RT @KingsMLC: Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that you can use…',
#  'Our #WordOfTheDay is in #Dutch. Have you been certain about something? Well, the Dutch have the perfect word that y… ',
#  'At the current rate, it will take 257 years to close the global gender gap. You can help expedite this with our pra… ',
#  'RT @AnisahEbrahimj1: Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If yo…',
#  'Are you ready to #Zoom your way back into #teams meetings?\n\nTell us about your experiences of using #videocalls. If… ',
#  'Our #WordOfTheDay is in #Polish. Find out what #Akademik means! #KCL #MLC #LearnLanguages ',
#  'Yu Rong is a senior student at Guangdong University of Foreign Studies. This year, she will go to #KCL for her post… ',
#  'RT @KingsMLC: Our #WordOfTheDay is in #French.  Did you know the origin of this phrase? #KCL #MLC #LearnLanguages ',
#  'Our #WordOfTheDay is in #French.  Did you know the origin of this phrase? #KCL #MLC #LearnLanguages ']

# %%
strings = ''.join(cleaned_tweets)
corpus = word_tokenize(strings)
corpus = [word.replace(" ", "") for word in corpus]
corpus = [word.lower() for word in corpus if word.isalpha()]

from nltk.corpus import stopwords
stopwords = list(stopwords.words('english'))
corpus = [word for word in corpus if word not in stopwords]

# %%
from wordcloud import WordCloud


wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',  
                min_font_size = 10).generate(str(corpus)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# Very popular with Twitter is also the analysis of followers. I don’t have so many. In fact, I am not really using Twitter much. But let’s still try. You can get my Twitter information by entering me = api.get_user(screen_name = 'tobias_blanke')

# %%
me = api.get_user(screen_name = 'tobias_blanke')
me.description
# Out:
# 'past philosopher and computer scientist; now digital arts and humanities; research infrastructure; analytics and synthetics'

# %% [markdown]
# It’s me! My followers are a little bit more interesting. We can retrieve by going throug api.followers('tobias_blanke')

# %%
# get first 20 followers
for follower in api.followers('tobias_blanke'): 
    print(follower.screen_name)
# Out:
# dpauschinger
# lpflorentino
# IcdsUva
# FaizIkramulla
# uva_dsc
# ch_starke
# JusDigitale
# LidiaDutkiewicz
# mdermentzi
# Marta_Marchiori
# fotisja
# MashmoolAmir
# s_lehuede
# KatherineBode
# JERRY66TRUELOVE
# markcote
# laragard_
# ASchjoett
# influencerlabor
# EuropeanaTech

# %% [markdown]
# I haven’t explained it yet, but Twitter limits the amount of API calls you can do at any moment in time, which is often an issue if you retrieve a lot of followers from accounts like Donalds Trump’s. Rate limits are often one of the biggest issues in Twitter analysis once the data gets a bit bigger. Check it out at https://dev.twitter.com/rest/public/rate-limiting. You will find plenty of people online who complain.
#
# Which is also something that can happen while trying to access the information that we try to extract in this assignment, just in case that happens you can find a csv file with the same info in data.

# %% [markdown]
# Let's first get the ids of all the followers

# %%
# Get list of al the follower ids (https://towardsdatascience.com/how-to-download-and-visualize-your-twitter-network-f009dbbf107b)
tb_id = me.id
user = [tb_id]
follower_list = []
for user in user:
    followers = []
    try:
        for page in tweepy.Cursor(api.followers_ids, user_id=user).pages():
            followers.extend(page)
            print(len(followers))
    except tweepy.TweepError:
        print("error")
        continue
    follower_list.append(followers)
# Out:
# 734

# %% [markdown]
# A key measure of my own importance on Twitter is the importance of the people who follow me. Does this make sense? Of course it does, as with important followers you can influence a lot of people. Let’s plot this measure and get an overview of the friends and followers of those who follow me.
# To do so we first want to create a dataframe that contains all my followers and their follower and friend count.

# %%
# Create dataframe
import pandas as pd

df = pd.DataFrame(columns=['user','follower'])
df['follower'] = follower_list[0]
df['user'] = tb_id

# %%
df
# Out:
#          user             follower
# 0    57082583            930539844
# 1    57082583   902178887672758273
# 2    57082583  1159505135011356675
# 3    57082583           3306825820
# 4    57082583  1320686621877035009
# ..        ...                  ...
# 729  57082583             22186527
# 730  57082583             92708232
# 731  57082583             77319148
# 732  57082583             66979272
# 733  57082583             66938950
#
# [734 rows x 2 columns]

# %%
followers = follower_list[0]
fol_count = []
for follower in followers[:200]:
    try:
        user = api.get_user(follower)
        count = user.followers_count
        fol_count.append(count)
    except tweepy.TweepError:
        fol_count.append(0)
        print("error")
        continue

# %%
df200 = df.head(200)

# %%
df200['follower_count'] = fol_count
# Out:
# <ipython-input-127-d47355f46424>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df200['follower_count'] = fol_count

# %%
df200
# Out:
#          user             follower  follower_count
# 0    57082583  1377139631905382411               0
# 1    57082583             17826845            1086
# 2    57082583   825790087560564738             525
# 3    57082583           2153236472              42
# 4    57082583  1356368233943625729              45
# ..        ...                  ...             ...
# 195  57082583            114441145            1001
# 196  57082583           2388843638              50
# 197  57082583            284455405            2840
# 198  57082583             14979635            5534
# 199  57082583            733354938              69
#
# [200 rows x 3 columns]

# %%
friends_count = user.friends_count 

friends_count = []
for follower in followers:
    try:
        user = api.get_user(follower)
        count = user.friends_count
        friends_count.append(count)
    except tweepy.TweepError:
        friends_count.append(0)
        print("error")
        continue
# Out:
# Rate limit reached. Sleeping for: 8
# Rate limit reached. Sleeping for: 818
# error
# Rate limit reached. Sleeping for: 818

# %%
df200['friends_count'] = friends_count
# Out:
# <ipython-input-124-42fd9b464d8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df200['friends_count'] = friends_count

# %%
df200.to_csv('df200.csv')
df200
# Out:
#          user             follower  follower_count  friends_count
# 0    57082583            744462961               0              0
# 1    57082583  1321135141729771524              54            164
# 2    57082583  1130775067154178049             306            756
# 3    57082583            179177557             169            529
# 4    57082583           1205111988            1575           2675
# ..        ...                  ...             ...            ...
# 195  57082583             17378128            1139           1512
# 196  57082583           1498487264             748            918
# 197  57082583             15924767             328            335
# 198  57082583             81944514               8             61
# 199  57082583            171892955            6826           7502
#
# [200 rows x 4 columns]

# %%
df200.plot.scatter(x='friends_count', y='follower_count',)
# Out:
# <AxesSubplot:xlabel='friends_count', ylabel='follower_count'>

# %% [markdown]
# Ok, there are not too many strong performers in my followers’ list. In order to confirm this, let’s check the counts for all my followers with a plot.

# %%
# Need to reload entire assignment first
# df200['follower_count'].count_values.plot()

# %% [markdown]
# So, most of my followers do not have too many followers themselves apart from one outlier. My influence is really limited. Let’s quickly move on then.
#
# Social network analysis is really important both in social and cultural analytics. It uses graphs to explain and analyse social relations. We have already started talking about social networks. We looked into my followers and those friends that I am following. Then, we investigated the friends of these friends and the followers of these followers. To build these kinds of relationships and map them onto graphs to visualise and analyse them is really what social networks are all about.
#
# We would like to build a graph of my friends and followers. We already have the followers, let's now reterive their screen names.
#
# Because graph visualisation can quickly get confusing if there are too many items to represent, we would like to limit the number of friends and followers to 20.

# %%
screen_names = []
for follower in followers[:20]:
    try:
        user = api.get_user(follower)
        name = user.screen_name
        print(name)
        screen_names.append(name)
    except tweepy.TweepError:
        screen_names.append('error')
        print("error")
        continue
# Out:
# error
# I_Dullaert
# J_Baruck
# sara_altamirano
# Biometricstate
# HxxxKxxx
# hughmacabre
# LeoImpett
# BhatnagarPrerak
# pieldeasno
# disruptberlin
# milanvanlange
# Nielbo23
# Res4Publica
# artston49456971
# atav1k
# chrbutler
# SwaTwee
# melvinwevers
# nieniewieder
# ViolaLorella
# FNaghshvarian
# UrszulaDeger
# JWI_Share_Econ
# Electric_Soups
# cgmsnoek
# Eirini_N
# annliffey
# marilia_gehrke
# Marloes0910
# ayeemacaraig
# skoopit
# fabianlferrari
# aldmilne
# TanjaKersevan
# Annegre42770179
# dude_crooks
# mvaldeb
# quyendao1711
# Jules_a_Berlin
# the_username69
# filmstarstudies
# anjabechmann
# yung_tupp
# luketosborne
# MarieBlond_
# sosurie
# lynxlynxly
# _JamesDutton_
# jbruehl
# AikateriniMnie
# JWI_DigiDem
# FabioRichterCH
# lee_bcg
# EdisonKonesha
# kuziemsky
# divijualsuspect
# thatcsteacher
# NounouBao
# DataPublicsRUC
# LuanQinglin
# JoanneKuai
# libra10014
# pbdevries
# alkksl
# zhaod520
# SusanaAiresG
# SvenjaHagenhoff
# X1fter
# rasa_bocyte
# CarolinIschen
# ashwinjm
# nonintuitive
# embreuer
# carobirdsall
# hubertguillaud
# eceelbeyi
# karakittel
# DLuitse
# nestybird
# veeebka
# Fabibiwasabi
# JessicaPranger
# DAMavoinmuisti
# _johnoshea
# MargheFantoli
# KthrnMeyer
# technoflesh
# JAlfredRock
# justjadez_
# Dimitri_VdM
# Nadya_Purtova
# ivozandhuis
# roxana_pomplun
# suzanneadema
# mjgbakker
# EGeertsPhD
# CuriousChemist4
# bhan_pervez
# SussexHumsLab
# lostintime2013
# wjb_mattingly
# HumaneAI2
# gjjdjbr
# leofn3
# jeu1987
# jlinabary
# aikvaneemeren
# anamariadutceac
# bramiozo
# PhiMeyer
# eric__eggert
# da_loick
# ArielBlueLucky
# MaxRossmann
# NatalieJester
# vanessa_ugolini
# nicalpert
# UoY_SATSU
# DrAlexVoss
# BEN_JAM1N
# yk4147
# Logic_Cognition
# ruyhliu
# mtwjmsdns
# federicarusso
# nescio13
# Vir2alinteriors
# pavesipavesi
# w_achbari
# TimeMachineEU
# citizen_sense
# FennaImara
# martaespuny
# SonjaSmets
# JaneeShen
# NetMev
# rutrut
# pinbarlas
# IrisProff
# MariKetz
# gimenadelr
# gaia_casagrande
# LucaVigano68
# BenediktLoewe
# jjnoordegraaf
# nicsuzor
# ahmetmiracson
# ARIAS_amsterdam
# MartijnKleppe
# Papadopoulos_C
# VilleAula
# aribeirojr
# CamiGottlieb
# tihanakrajnovic
# ChrstSchulz
# Stuckmist
# sunil_abraham
# MulumbaOnan
# uva_gdc
# Shiera35965366
# DARIAH_SI
# a_nother_web
# shalaby_n
# evoluchico
# palmerabollo
# javiergb_com
# anniekderuijter
# sandervhaperen
# __chengh
# FloraLysen
# securityflows
# tomvannuenen
# rvaneijk
# annaidahd
# _vecna
# FelixTreguer
# Grete_60664
# ISICambridge
# SeamusRoss
# martijnhartog
# RobertvDoesburg
# hanedhinda
# nicholas_till
# RoserPujadas1
# cats_wolf
# MullerCatelijne
# VincentBptst
# firatberkk
# JenniexWilliams
# KCL_CSRG
# JeanSpritzer
# LeitaoMarquesEP
# Paul_Dunshirn
# georgie
# pustovek
# ikkibop
# johedesan
# gherya
# Quebreda

# %%
df20 = df200.head(20)
df20['screen_name_follower'] = screen_names
df20['screen_name_user'] = api.get_user(tb_id).screen_name
df20

# %%
# Check the friends of user/source
user = [tb_id]
n = 1
for user in user:
    friends = []
    screen_name_friends = []
    try:
        if n != 20:
            for friend in tweepy.Cursor(api.friends_ids, user_id=user).items():
                n+=1
                friends.append(friend)
                user = api.get_user(friend)
                name = user.screen_name
                screen_name_friends.append(name)
    except tweepy.TweepError:
        friends.append('error')
        print("error")
        continue

# %%
df_friends = pd.DataFrame(columns=['user','follower'])
df_friends['user'] = friends
df_friends['follower'] = tb_id

# %%
df_friends['screen_name_follower'] = api.get_user(tb_id).screen_name
df_friends['screen_name_user'] = screen_name_friends

# %%
df_friends['follower_count'] = len(followers)
df_friends['friends_count'] = len(friends)

# %%
df_friends.to_csv('df_friends.csv')
df_friends
# Out:
#          user  follower screen_name_follower screen_name_user  follower_count  \
# 0   527496778  57082583        tobias_blanke         abbey_st           19647
# 1    19907166  57082583        tobias_blanke         nolauren           19647
# 2    14389093  57082583        tobias_blanke             jwyg           19647
# 3    58492780  57082583        tobias_blanke    joshmacfadyen           19647
# 4   948243710  57082583        tobias_blanke         HxxxKxxx           19647
# ..        ...       ...                  ...              ...             ...
# 84   55229892  57082583        tobias_blanke    torstenreimer           19647
# 85   29360785  57082583        tobias_blanke     simon_mahony           19647
# 86   14073534  57082583        tobias_blanke          mhedges           19647
# 87   77319148  57082583        tobias_blanke    Ben_OLoughlin           19647
# 88   28311044  57082583        tobias_blanke           agiati           19647
#
#     friends_count
# 0              89
# 1              89
# 2              89
# 3              89
# 4              89
# ..            ...
# 84             89
# 85             89
# 86             89
# 87             89
# 88             89
#
# [89 rows x 6 columns]

# %%
merge = pd.concat([df20,df_friends])
merge
# Out:
#         user             follower  follower_count  friends_count  \
# 0   57082583            744462961               0              0
# 1   57082583  1321135141729771524              54            164
# 2   57082583  1130775067154178049             306            756
# 3   57082583            179177557             169            529
# 4   57082583           1205111988            1575           2675
# ..       ...                  ...             ...            ...
# 84  55229892             57082583           19647             89
# 85  29360785             57082583           19647             89
# 86  14073534             57082583           19647             89
# 87  77319148             57082583           19647             89
# 88  28311044             57082583           19647             89
#
#    screen_name_follower screen_name_user
# 0                 error    tobias_blanke
# 1            I_Dullaert    tobias_blanke
# 2              J_Baruck    tobias_blanke
# 3       sara_altamirano    tobias_blanke
# 4        Biometricstate    tobias_blanke
# ..                  ...              ...
# 84        tobias_blanke    torstenreimer
# 85        tobias_blanke     simon_mahony
# 86        tobias_blanke          mhedges
# 87        tobias_blanke    Ben_OLoughlin
# 88        tobias_blanke           agiati
#
# [289 rows x 6 columns]

# %%
graphdata = merge

# %%
nodes = pd.DataFrame(columns=['userid', 'user_name'])
nodes['userid'] = graphdata.follower.unique()
nodes['user_name'] = graphdata.screen_name_follower.unique()

relations = pd.DataFrame(columns=['user', 'follower'])
relations['user'] = graphdata['user']
relations['follower'] = graphdata['follower']

# %%
nodes
# Out:
#                   userid        user_name
# 0              744462961            error
# 1    1321135141729771524       I_Dullaert
# 2    1130775067154178049         J_Baruck
# 3              179177557  sara_altamirano
# 4             1205111988   Biometricstate
# ..                   ...              ...
# 196           1498487264          ikkibop
# 197             15924767        johedesan
# 198             81944514           gherya
# 199            171892955         Quebreda
# 200             57082583    tobias_blanke
#
# [201 rows x 2 columns]

# %%
import igraph
from igraph import *
graph = Graph(directed=True)

# %%
graph = Graph.DictList(
          vertices=nodes.to_dict('records'),
          edges=relations.to_dict('records'),
          directed=True,
          vertex_name_attr='userid',
          edge_foreign_keys=('follower', 'user'));

# %%
print(graph)
# Out:
# IGRAPH D--- 274 289 --
# + attr: user_name (v), userid (v), follower (e), user (e)
# + edges:
# 0->200 1->200 2->200 3->200 4->200 5->200 6->200 7->200 8->200 9->200 10->200
# 11->200 12->200 13->200 14->200 15->200 16->200 17->200 18->200 19->200
# 20->200 21->200 22->200 23->200 24->200 25->200 26->200 27->200 28->200
# 29->200 30->200 31->200 32->200 33->200 34->200 35->200 36->200 37->200
# 38->200 39->200 40->200 41->200 42->200 43->200 44->200 45->200 46->200
# 47->200 48->200 49->200 50->200 51->200 52->200 53->200 54->200 55->200
# 56->200 57->200 58->200 59->200 60->200 61->200 62->200 63->200 64->200
# 65->200 66->200 67->200 68->200 69->200 70->200 71->200 72->200 73->200
# 74->200 75->200 76->200 77->200 78->200 79->200 80->200 81->200 82->200
# 83->200 84->200 85->200 86->200 87->200 88->200 89->200 90->200 91->200
# 92->200 93->200 94->200 95->200 96->200 97->200 98->200 99->200 100->200
# 101->200 102->200 103->200 104->200 105->200 106->200 107->200 108->200
# 109->200 110->200 111->200 112->200 113->200 114->200 115->200 116->200
# 117->200 118->200 119->200 120->200 121->200 122->200 123->200 124->200
# 125->200 126->200 127->200 128->200 129->200 130->200 131->200 132->200
# 133->200 134->200 135->200 136->200 137->200 138->200 139->200 140->200
# 141->200 142->200 143->200 144->200 145->200 146->200 147->200 148->200
# 149->200 150->200 151->200 152->200 153->200 154->200 155->200 156->200
# 157->200 158->200 159->200 160->200 161->200 162->200 163->200 164->200
# 165->200 166->200 167->200 168->200 169->200 170->200 171->200 172->200
# 173->200 174->200 175->200 176->200 177->200 178->200 179->200 180->200
# 181->200 182->200 183->200 184->200 185->200 186->200 187->200 188->200
# 189->200 190->200 191->200 192->200 193->200 194->200 195->200 196->200
# 197->200 198->200 199->200 200->201 200->202 200->203 200->204 200->5 200->205
# 200->145 200->196 200->206 200->207 200->208 200->25 200->209 200->210 200->27
# 200->211 200->212 200->171 200->149 200->213 200->74 200->214 200->112
# 200->215 200->216 200->217 200->218 200->219 200->125 200->159 200->134
# 200->220 200->221 200->222 200->223 200->224 200->225 200->182 200->179
# 200->186 200->226 200->227 200->228 200->229 200->230 200->231 200->232
# 200->233 200->234 200->143 200->235 200->236 200->237 200->238 200->239
# 200->240 200->241 200->242 200->243 200->244 200->245 200->246 200->247
# 200->248 200->249 200->250 200->251 200->252 200->253 200->254 200->255
# 200->256 200->257 200->258 200->259 200->260 200->261 200->262 200->263
# 200->264 200->265 200->266 200->267 200->268 200->269 200->270 200->271
# 200->272 200->273

# %%
plot(graph, vertex_label=graph.vs['user_name'])
