# %% [markdown]
# # Nowcasting with Google Trends

# %% [markdown]
# Google Trends is a public web facility of Google Inc., based on Google Search, that shows how often a particular search-term is entered relative to the total search-volume across various regions of the world, and in various languages (https://en.wikipedia.org/wiki/Google_Trends).

# %% [markdown]
# Google Trends is a useful way to compare changes in popularity of certain search terms over time, and Google Trends data can be used as a proxy for all sorts of difficult-to-measure quantities like economic activity and disease propagation.
#
# Compared to the social media tools we have seen so far, it has the advantage that we do not depend on users giving us information directly about their state of mind, but we can derive it from their search behaviour and information needs:
#
# - Google's own research has shown that 'the volume of Google searches for particular keywords is correlated with related economic indicators'. http://blog.revolutionanalytics.com/2009/09/google-uses-r-to-predict-economic-activity.html
# - The purpose of Google Flu Trends (GFT) is to use search keyword trends from Google.com to produce a daily estimate, or nowcast, of the occurrence of flu two weeks in advance of publication of official surveillance data. (https://research.google.com/pubs/pub41763.html). This method has also been called 'Nowcasting' and has been controversial (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4522652/).

# %%
import pandas as pd    
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# Let's execute a simple query and find out about the interest in KCL in GB compared to our German partner university Humboldt University Berlin (HUB).

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB')
df1 = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list=['KCL'], geo='DE')
df2 = pytrend.interest_over_time()

# %%
plt.plot(df1['KCL'], label='GB')
plt.plot(df2['KCL'], label='DE')
plt.legend()
plt.show()

# %% [markdown]
# KCL clearly has seasonal peaks and lows. Why do you think this is the case?
#
# The plot function plots the time series interest_over_time, which we can also access with head.

# %%
df2.head()
# Out:
#             KCL isPartial
# date
# 2016-12-11   25     False
# 2016-12-18   27     False
# 2016-12-25   28     False
# 2017-01-01   25     False
# 2017-01-08   47     False

# %% [markdown]
# When people search for a certain topic they also search for something related, these are called related topics.
# We can acces them through related_topics() which returns a dictionary of related queries

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB')
pytrend.related_topics()
# Out:
# {'KCL': {'rising':     value formattedValue                                               link  \
#   0   35450       Breakout  /trends/explore?q=/m/02tfkk&date=today+5-y&geo=GB
#   1    2200        +2,200%  /trends/explore?q=/m/04n_1m&date=today+5-y&geo=GB
#   2     250          +250%  /trends/explore?q=/m/06_wzsw&date=today+5-y&ge...
#   3     200          +200%  /trends/explore?q=/m/0150d_&date=today+5-y&geo=GB
#   4     200          +200%   /trends/explore?q=/m/0lbfv&date=today+5-y&geo=GB
#   5     200          +200%   /trends/explore?q=/m/02j62&date=today+5-y&geo=GB
#   6     200          +200%  /trends/explore?q=/m/01rk91&date=today+5-y&geo=GB
#   7     180          +180%  /trends/explore?q=/m/02nmgv&date=today+5-y&geo=GB
#   8     160          +160%   /trends/explore?q=/m/0l5mz&date=today+5-y&geo=GB
#   9     160          +160%   /trends/explore?q=/m/05qt0&date=today+5-y&geo=GB
#   10    150          +150%  /trends/explore?q=/m/02cq61&date=today+5-y&geo=GB
#   11    140          +140%  /trends/explore?q=/m/03bwzr4&date=today+5-y&ge...
#   12     90           +90%  /trends/explore?q=/m/016t_3&date=today+5-y&geo=GB
#   13     80           +80%  /trends/explore?q=/m/02p0qmm&date=today+5-y&ge...
#   14     70           +70%   /trends/explore?q=/m/0465_&date=today+5-y&geo=GB
#   15     70           +70%   /trends/explore?q=/m/06mq7&date=today+5-y&geo=GB
#   16     60           +60%   /trends/explore?q=/m/0dplh&date=today+5-y&geo=GB
#   17     50           +50%  /trends/explore?q=/m/027bgp7&date=today+5-y&ge...
#   18     40           +40%  /trends/explore?q=/m/04zx3q1&date=today+5-y&ge...
#   19     40           +40%  /trends/explore?q=/g/11cs5f75lv&date=today+5-y...
#
#           topic_mid                     topic_title  \
#   0       /m/02tfkk                      Bush House
#   1       /m/04n_1m                 Student affairs
#   2      /m/06_wzsw  The Dickson Poon School of Law
#   3       /m/0150d_              Potassium chloride
#   4        /m/0lbfv    The University of Manchester
#   5        /m/02j62                       Economics
#   6       /m/01rk91                      Internship
#   7       /m/02nmgv                   Academic term
#   8        /m/0l5mz           International affairs
#   9        /m/05qt0                        Politics
#   10      /m/02cq61                  Master of Laws
#   11     /m/03bwzr4               Master of Science
#   12      /m/016t_3                 Master's Degree
#   13     /m/02p0qmm                         College
#   14       /m/0465_                      John Keats
#   15       /m/06mq7                         Science
#   16       /m/0dplh       University College London
#   17     /m/027bgp7                School timetable
#   18     /m/04zx3q1            Doctor of Philosophy
#   19  /g/11cs5f75lv                             UCL
#
#                                 topic_type
#   0            Building in London, England
#   1                                  Topic
#   2          Law school in London, England
#   3                                  Topic
#   4      University in Manchester, England
#   5                         Field of study
#   6                                  Topic
#   7                                  Topic
#   8                         Field of study
#   9                         Field of study
#   10                                Degree
#   11                                Degree
#   12                                Degree
#   13                       School category
#   14                          English poet
#   15                                 Topic
#   16  Public university in London, England
#   17                                 Topic
#   18                                Degree
#   19                                 Topic  ,
#   'top':     value formattedValue  hasData  \
#   0     100            100     True
#   1      87             87     True
#   2      52             52     True
#   3      24             24     True
#   4       8              8     True
#   5       8              8     True
#   6       6              6     True
#   7       4              4     True
#   8       2              2     True
#   9       2              2     True
#   10      2              2     True
#   11      2              2     True
#   12      2              2     True
#   13      2              2     True
#   14      1              1     True
#   15      1              1     True
#   16      1              1     True
#   17      1              1     True
#   18      1              1     True
#   19      1              1     True
#   20      0             <1     True
#   21      0             <1     True
#   22      0             <1     True
#   23      0             <1     True
#   24      0             <1     True
#
#                                                    link      topic_mid  \
#   0   /trends/explore?q=/g/11cs5f51yx&date=today+5-y...  /g/11cs5f51yx
#   1   /trends/explore?q=/m/014xf6&date=today+5-y&geo=GB      /m/014xf6
#   2   /trends/explore?q=/m/05yplb&date=today+5-y&geo=GB      /m/05yplb
#   3    /trends/explore?q=/m/02nf_&date=today+5-y&geo=GB       /m/02nf_
#   4   /trends/explore?q=/m/014cnc&date=today+5-y&geo=GB      /m/014cnc
#   5   /trends/explore?q=/m/0150d_&date=today+5-y&geo=GB      /m/0150d_
#   6    /trends/explore?q=/m/04h8h&date=today+5-y&geo=GB       /m/04h8h
#   7   /trends/explore?q=/m/02p0qmm&date=today+5-y&ge...     /m/02p0qmm
#   8    /trends/explore?q=/m/0465_&date=today+5-y&geo=GB       /m/0465_
#   9   /trends/explore?q=/g/11cs5f75lv&date=today+5-y...  /g/11cs5f75lv
#   10   /trends/explore?q=/m/0dplh&date=today+5-y&geo=GB       /m/0dplh
#   11  /trends/explore?q=/m/027bgp7&date=today+5-y&ge...     /m/027bgp7
#   12  /trends/explore?q=/m/05sc3k&date=today+5-y&geo=GB      /m/05sc3k
#   13   /trends/explore?q=/m/06mq7&date=today+5-y&geo=GB       /m/06mq7
#   14   /trends/explore?q=/m/01_x9&date=today+5-y&geo=GB       /m/01_x9
#   15  /trends/explore?q=/m/04zx3q1&date=today+5-y&ge...     /m/04zx3q1
#   16  /trends/explore?q=/m/016t_3&date=today+5-y&geo=GB      /m/016t_3
#   17   /trends/explore?q=/m/05qt0&date=today+5-y&geo=GB       /m/05qt0
#   18  /trends/explore?q=/m/03bwzr4&date=today+5-y&ge...     /m/03bwzr4
#   19   /trends/explore?q=/m/02j62&date=today+5-y&geo=GB       /m/02j62
#   20  /trends/explore?q=/m/04n_1m&date=today+5-y&geo=GB      /m/04n_1m
#   21  /trends/explore?q=/m/02tfkk&date=today+5-y&geo=GB      /m/02tfkk
#   22  /trends/explore?q=/m/01rk91&date=today+5-y&geo=GB      /m/01rk91
#   23   /trends/explore?q=/m/0l5mz&date=today+5-y&geo=GB       /m/0l5mz
#   24  /trends/explore?q=/m/06_wzsw&date=today+5-y&ge...     /m/06_wzsw
#
#                                 topic_title  \
#   0                   King's College London
#   1                   King's College London
#   2   King's College London Students' Union
#   3                                   Email
#   4                                 Student
#   5                      Potassium chloride
#   6                                 Library
#   7                                 College
#   8                              John Keats
#   9                                     UCL
#   10              University College London
#   11                       School timetable
#   12                     Outlook on the web
#   13                                Science
#   14                                 Campus
#   15                   Doctor of Philosophy
#   16                        Master's Degree
#   17                               Politics
#   18                      Master of Science
#   19                              Economics
#   20                        Student affairs
#   21                             Bush House
#   22                             Internship
#   23                  International affairs
#   24         The Dickson Poon School of Law
#
#                                 topic_type
#   0                                  Topic
#   1   Public university in London, England
#   2                                  Topic
#   3                                  Topic
#   4                                  Topic
#   5                                  Topic
#   6                                  Topic
#   7                        School category
#   8                           English poet
#   9                                  Topic
#   10  Public university in London, England
#   11                                 Topic
#   12                                 Topic
#   13                                 Topic
#   14                                 Topic
#   15                                Degree
#   16                                Degree
#   17                        Field of study
#   18                                Degree
#   19                        Field of study
#   20                                 Topic
#   21           Building in London, England
#   22                                 Topic
#   23                        Field of study
#   24         Law school in London, England  }}

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', timeframe='today 1-m')

df3 = pytrend.interest_over_time()
df3.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# We can search  other Google applications, too. For instance, news and youtube.

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', gprop='news')

df4 = pytrend.interest_over_time()
df4.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', gprop='youtube')

df5 = pytrend.interest_over_time()
df5.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# That's. It really is that easy to get exciting data from Google.
#
# Your exercise would be to define your own two sites you would like to compare. What do you discover?
