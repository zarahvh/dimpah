# %% [markdown]
# # Nowcasting with Google Trends

# %% [markdown]
# Google Trends is a public web facility of Google Inc., based on Google Search, that shows how often a particular search-term is entered relative to the total search-volume across various regions of the world, and in various languages (https://en.wikipedia.org/wiki/Google_Trends).

# %% [markdown]
# Google Trends is a useful way to compare changes in popularity of certain search terms over time, and Google Trends data can be used as a proxy for all sorts of difficult-to-measure quantities like economic activity and disease propagation.
#
# Compared to the social media tools we have seen so far, it has the advantage that we do not depend on users giving us information directly about their state of mind, but we can derive it from their search behaviour and information needs:
#
# - Google's own research has shown that 'the volume of Google searches for particular keywords is correlated with related economic indicators'. http://blog.revolutionanalytics.com/2009/09/google-uses-r-to-predict-economic-activity.html
# - The purpose of Google Flu Trends (GFT) is to use search keyword trends from Google.com to produce a daily estimate, or nowcast, of the occurrence of flu two weeks in advance of publication of official surveillance data. (https://research.google.com/pubs/pub41763.html). This method has also been called 'Nowcasting' and has been controversial (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4522652/).

# %%
import pandas as pd    
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# Let's execute a simple query and find out about the interest in KCL in GB compared to our German partner university Humboldt University Berlin (HUB).

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB')
df1 = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list=['KCL'], geo='DE')
df2 = pytrend.interest_over_time()

# %%
plt.plot(df1['KCL'], label='GB')
plt.plot(df2['KCL'], label='DE')
plt.legend()
plt.show()

# %% [markdown]
# KCL clearly has seasonal peaks and lows. Why do you think this is the case?
#
# The plot function plots the time series interest_over_time, which we can also access with head.

# %%
df2.head()
# Out:
#             KCL  isPartial
# date
# 2016-10-09   82      False
# 2016-10-16  100      False
# 2016-10-23   80      False
# 2016-10-30   75      False
# 2016-11-06   68      False

# %% [markdown]
# When people search for a certain topic they also search for something related, these are called related topics.
# We can acces them through related_topics() which returns a dictionary of related queries

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB')
pytrend.related_topics()
# Out:
# {'KCL': {'rising':     value formattedValue                                               link  \
#   0   36800       Breakout  /trends/explore?q=/m/02tfkk&date=today+5-y&geo=GB
#   1   11250       Breakout  /trends/explore?q=/g/11c5xv8p_1&date=today+5-y...
#   2     500          +500%  /trends/explore?q=/g/11cnl7lvd7&date=today+5-y...
#   3     450          +450%   /trends/explore?q=/m/0bwd5&date=today+5-y&geo=GB
#   4     250          +250%  /trends/explore?q=/m/02_xgp2&date=today+5-y&ge...
#   5     200          +200%  /trends/explore?q=/m/026m3y&date=today+5-y&geo=GB
#   6     200          +200%  /trends/explore?q=/m/07fw8_&date=today+5-y&geo=GB
#   7     200          +200%  /trends/explore?q=/m/016t_3&date=today+5-y&geo=GB
#   8     170          +170%  /trends/explore?q=/g/11b7cjs93p&date=today+5-y...
#   9     170          +170%  /trends/explore?q=/m/0134hp&date=today+5-y&geo=GB
#   10     80           +80%  /trends/explore?q=/m/02p0qmm&date=today+5-y&ge...
#   11     50           +50%  /trends/explore?q=/m/0150d_&date=today+5-y&geo=GB
#   12     50           +50%   /trends/explore?q=/m/06mq7&date=today+5-y&geo=GB
#   13     40           +40%   /trends/explore?q=/m/06cs1&date=today+5-y&geo=GB
#
#           topic_mid                      topic_title  \
#   0       /m/02tfkk                       Bush House
#   1   /g/11c5xv8p_1       King's Talent Bank Limited
#   2   /g/11cnl7lvd7                Admissions Office
#   3        /m/0bwd5                  Business school
#   4      /m/02_xgp2                        Doctorate
#   5       /m/026m3y  Queen Mary University of London
#   6       /m/07fw8_             Undergraduate degree
#   7       /m/016t_3                  Master's Degree
#   8   /g/11b7cjs93p                        Cambridge
#   9       /m/0134hp                          Academy
#   10     /m/02p0qmm                          College
#   11      /m/0150d_               Potassium chloride
#   12       /m/06mq7                          Science
#   13       /m/06cs1                         Research
#
#                                 topic_type
#   0            Building in London, England
#   1                                  Topic
#   2                                  Topic
#   3                        School category
#   4                                 Degree
#   5   Public university in London, England
#   6                                 Degree
#   7                                 Degree
#   8                                  Topic
#   9                        School category
#   10                       School category
#   11                                 Topic
#   12                                 Topic
#   13                     Organization type  ,
#   'top':     value formattedValue  hasData  \
#   0     100            100     True
#   1      99             99     True
#   2      25             25     True
#   3       9              9     True
#   4       7              7     True
#   5       6              6     True
#   6       5              5     True
#   7       4              4     True
#   8       2              2     True
#   9       2              2     True
#   10      2              2     True
#   11      2              2     True
#   12      1              1     True
#   13      1              1     True
#   14      1              1     True
#   15      1              1     True
#   16      1              1     True
#   17      1              1     True
#   18      1              1     True
#   19      1              1     True
#   20      0             <1     True
#   21      0             <1     True
#   22      0             <1     True
#   23      0             <1     True
#   24      0             <1     True
#
#                                                    link      topic_mid  \
#   0   /trends/explore?q=/g/11cs5f51yx&date=today+5-y...  /g/11cs5f51yx
#   1   /trends/explore?q=/m/014xf6&date=today+5-y&geo=GB      /m/014xf6
#   2    /trends/explore?q=/m/02nf_&date=today+5-y&geo=GB       /m/02nf_
#   3    /trends/explore?q=/m/0465_&date=today+5-y&geo=GB       /m/0465_
#   4   /trends/explore?q=/m/014cnc&date=today+5-y&geo=GB      /m/014cnc
#   5    /trends/explore?q=/m/04h8h&date=today+5-y&geo=GB       /m/04h8h
#   6   /trends/explore?q=/m/0150d_&date=today+5-y&geo=GB      /m/0150d_
#   7   /trends/explore?q=/m/02p0qmm&date=today+5-y&ge...     /m/02p0qmm
#   8   /trends/explore?q=/g/11cs5f75lv&date=today+5-y...  /g/11cs5f75lv
#   9   /trends/explore?q=/m/017xch&date=today+5-y&geo=GB      /m/017xch
#   10   /trends/explore?q=/m/0dplh&date=today+5-y&geo=GB       /m/0dplh
#   11  /trends/explore?q=/m/016t_3&date=today+5-y&geo=GB      /m/016t_3
#   12   /trends/explore?q=/m/04sh3&date=today+5-y&geo=GB       /m/04sh3
#   13  /trends/explore?q=/m/05sc3k&date=today+5-y&geo=GB      /m/05sc3k
#   14  /trends/explore?q=/m/027bgp7&date=today+5-y&ge...     /m/027bgp7
#   15   /trends/explore?q=/m/01_x9&date=today+5-y&geo=GB       /m/01_x9
#   16   /trends/explore?q=/m/06cs1&date=today+5-y&geo=GB       /m/06cs1
#   17   /trends/explore?q=/m/06mq7&date=today+5-y&geo=GB       /m/06mq7
#   18  /trends/explore?q=/m/02t4qp&date=today+5-y&geo=GB      /m/02t4qp
#   19  /trends/explore?q=/m/026m3y&date=today+5-y&geo=GB      /m/026m3y
#   20  /trends/explore?q=/m/02tfkk&date=today+5-y&geo=GB      /m/02tfkk
#   21  /trends/explore?q=/m/0134hp&date=today+5-y&geo=GB      /m/0134hp
#   22  /trends/explore?q=/m/07fw8_&date=today+5-y&geo=GB      /m/07fw8_
#   23  /trends/explore?q=/g/11b7cjs93p&date=today+5-y...  /g/11b7cjs93p
#   24  /trends/explore?q=/g/11cnl7lvd7&date=today+5-y...  /g/11cnl7lvd7
#
#                           topic_title                            topic_type
#   0             King's College London                                 Topic
#   1             King's College London  Public university in London, England
#   2                             Email                                 Topic
#   3                        John Keats                          English poet
#   4                           Student                                 Topic
#   5                           Library                                 Topic
#   6                Potassium chloride                                 Topic
#   7                           College                       School category
#   8                               UCL                                 Topic
#   9                 Microsoft Outlook                              Software
#   10        University College London  Public university in London, England
#   11                  Master's Degree                                Degree
#   12                         Medicine                                 Topic
#   13               Outlook on the web                                 Topic
#   14                 School timetable                                 Topic
#   15                           Campus                                 Topic
#   16                         Research                     Organization type
#   17                          Science                                 Topic
#   18         Kirchhoff's circuit laws                                 Topic
#   19  Queen Mary University of London  Public university in London, England
#   20                       Bush House           Building in London, England
#   21                          Academy                       School category
#   22             Undergraduate degree                                Degree
#   23                        Cambridge                                 Topic
#   24                Admissions Office                                 Topic  }}

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', timeframe='today 1-m')

df3 = pytrend.interest_over_time()
df3.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# We can search  other Google applications, too. For instance, news and youtube.

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', gprop='news')

df4 = pytrend.interest_over_time()
df4.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pytrend.build_payload(kw_list=['KCL'], geo='GB', gprop='youtube')

df5 = pytrend.interest_over_time()
df5.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# That's. It really is that easy to get exciting data from Google.
#
# Your exercise would be to define your own two sites you would like to compare. What do you discover?
